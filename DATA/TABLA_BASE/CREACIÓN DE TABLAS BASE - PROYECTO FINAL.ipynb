# %% [markdown]
# **IMPORTACIONES**

# %%
import pandas as pd
import itertools as it
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# **CREACIÓN DE TABLAS DE COLORES POR FACCIÓN**

# %%
#COLOR DE LAS FACCIONES
color_cab = ['rubio', 'rubio ceniza', 'rubio platino', 'castano', 'castano claro', 'castano oscuro',\
            'chocolate', 'negro', 'pelirrojo', 'caoba']
color_ojos = ['miel', 'verde', 'ambar', 'almendra', 'azul', 'marron oscuro', 'negro', 'gris']
color_piel = ['moreno / marron claro', 'moreno claro / dorado', 'amarillento', \
              'negro', 'rosada', 'blanco / palido', 'melocoton']

# %%
data1 = {'ID' : [e for e in range(len(color_cab))], 'COLORES' : color_cab,  'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'cabello'}
data2 = {'ID' : [e for e in range(len(color_ojos))], 'COLORES' : color_ojos,  'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'ojos'}
data3 = {'ID' : [e for e in range(len(color_piel))], 'COLORES' : color_piel, 'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'piel'}

# %%
#TABLAS
cabello = pd.DataFrame(data1)
ojos = pd.DataFrame(data2)
piel = pd.DataFrame(data3)

# %% [markdown]
# Debemos diferenciar entre la temperatura, el valor y el croma de cada color de las facciones, siendo los siguientes:
#
#   1. **TEMPERATURA**:
#
# *frios* = ['castaño oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / pálido',
#             'marrón oscuro', 'negro', 'azul', 'gris']
#
# *calidos* = ['rubio', 'castaño', 'castaño claro', 'pelirrojo', 'moreno / marrón claro', 'moreno claro / dorado',
#               'amarillento','negro', 'melocotón', 'miel', 'verde', 'ámbar', 'almendra', 'caoba']
#
#   2. **VALOR**:
#
# *claro* = ['rubio', 'castaño', 'castaño claro', 'pelirrojo',
#             'rubio platino', 'rubio ceniza', 'rosada', 'blanco /  pálido', 'amarillento', 'melocotón',
#             'miel', 'verde', 'ámbar', 'azul', 'gris', 'almendra']
#
# *oscuro* =['castaño oscuro', 'chocolate', 'negro', 'marrón oscuro', 'negro', 'moreno / marrón claro', 'moreno claro
#          dorado', 'negro', 'almendra', 'caoba']
#
#    3. **CROMA**:
#
# *brillante* - pieles, ojos y cabellos monocromáticos
#
# *suave* - pieles, ojos y cabellos con policromáticos (mechas o reflejos, ojos con más de un color, etc.)

# %%
claro = ['rubio', 'castano', 'castano claro', 'pelirrojo', \
            'rubio platino', 'rubio ceniza', 'rosada', 'blanco /  palido', 'amarillento', 'melocoton', \
            'miel', 'verde', 'ambar', 'azul', 'gris']

oscuro = ['castaño oscuro', 'chocolate', 'negro', 'marron oscuro', 'negro', 'moreno / marron claro', \
         'moreno claro / dorado', 'negro', 'almendra', 'caoba']

# %%
frios = ['castano oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido',\
            'marron oscuro', 'negro', 'azul', 'gris']

calidos = ['rubio', 'castaño', 'castaño claro', 'pelirrojo', 'moreno / marron claro', 'moreno claro / dorado',\
          'amarillento','negro', 'melocoton', 'miel', 'verde', 'ambar', 'almendra', 'caoba']

# %%
#COLUMNA'TEMPERATURA' - CABELLO
frios = ['castano oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido',\
            'marron oscuro', 'negro', 'azul', 'gris']
temp1 = []
for e in cabello.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

cabello.TEMP = temp1

# %%
#COLUMNA'TEMPERATURA' - OJOS
temp1 = []
for e in ojos.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

ojos.TEMP = temp1

# %%
#COLUMNA'TEMPERATURA' - PIEL
temp1 = []
for e in piel.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

piel.TEMP = temp1

# %%
#COLUMNA 'VALOR' - CABELLO
claro = ['rubio', 'castano', 'castano claro', 'pelirrojo', \
            'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido', 'amarillento', 'melocoton', \
            'miel', 'verde', 'ambar', 'azul', 'gris']
temp2 = []
for e in cabello.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

cabello.VALOR = temp2

# %%
cabello
# Out:
#    ID         COLORES    TEMP   VALOR     TIPO
# 0   0           rubio  cálido   claro  cabello
# 1   1    rubio ceniza    frío   claro  cabello
# 2   2   rubio platino    frío   claro  cabello
# 3   3         castano  cálido   claro  cabello
# 4   4   castano claro  cálido   claro  cabello
# 5   5  castano oscuro    frío  oscuro  cabello
# 6   6       chocolate    frío  oscuro  cabello
# 7   7           negro    frío  oscuro  cabello
# 8   8       pelirrojo  cálido   claro  cabello
# 9   9           caoba  cálido  oscuro  cabello

# %%
#COLUMNA 'VALOR' - OJOS
temp2 = []
for e in ojos.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

ojos.VALOR = temp2

# %%
ojos
# Out:
#    ID        COLORES    TEMP   VALOR  TIPO
# 0   0           miel  cálido   claro  ojos
# 1   1          verde  cálido   claro  ojos
# 2   2          ámbar  cálido   claro  ojos
# 3   3       almendra  cálido  oscuro  ojos
# 4   4           azul    frío   claro  ojos
# 5   5  marrón oscuro    frío  oscuro  ojos
# 6   6          negro    frío  oscuro  ojos
# 7   7           gris    frío   claro  ojos

# %%
#COLUMNA 'VALOR' - PIEL
temp2 = []
for e in piel.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

piel.VALOR = temp2

# %%
piel
# Out:
#    ID                COLORES    TEMP   VALOR  TIPO
# 0   0  moreno / marrón claro  cálido  oscuro  piel
# 1   1  moreno claro / dorado  cálido  oscuro  piel
# 2   2            amarillento  cálido   claro  piel
# 3   3                  negro    frío  oscuro  piel
# 4   4                 rosada    frío   claro  piel
# 5   5        blanco / pálido    frío   claro  piel
# 6   6              melocotón  cálido   claro  piel

# %%
#TABLA 'CROMA'
data4 = {'ID' : [1, 2], 'CROMA_CAB' : ['brillante', 'suave'], 'CROMA_OJOS' : ['brillante', 'suave'],\
        'CROMA_PIEL' : ['brillante', 'suave']}
croma = pd.DataFrame(data4)

# %% [markdown]
# Vamos a pasar las tablas a SQL ya que se nos facilita la combinación entre ellas

# %%
str_conn='mysql+pymysql://root:01051997Rm@localhost:3306/PROYECTO_FINAL'

cursor=create_engine(str_conn)

# %%
#cabello.to_sql(name='cabello', con=cursor, if_exists='replace', index=False)
#ojos.to_sql(name='ojos', con=cursor, if_exists='replace', index=False)
#piel.to_sql(name='piel', con=cursor, if_exists='replace', index=False)
#croma.to_sql(name='croma', con=cursor, if_exists='replace', index=False)

# %% [markdown]
# Traemos la tabla 'combinaciones' de MYSQL, ya que contiene todas las combinaciones posibles de colores de pelo, ojos y piel + los CROMAS

# %%
combinaciones = pd.read_csv('../TABLA_BASE/combinaciones_def.csv', sep = ';')

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL
# 0   rubio  gris  melocoton      suave      suave      suave
# 1   rubio  gris  melocoton      suave      suave  brillante
# 2   rubio  gris  melocoton      suave  brillante      suave
# 3   rubio  gris  melocoton      suave  brillante  brillante
# 4   rubio  gris  melocoton  brillante      suave      suave

# %% [markdown]
# Vamos a añadir 6 columnas más: TEMP_CABELLO, TEMP_OJOS, TEMP_PIEL, VALOR_CABELLO, VALOR_OJOS Y VALOR_PIEL.
# De esta forma, luego será más fácil identificar la paleta que corresponda a cada uno de los casos.

# %%
#Definimos los casos de temperatura para cada fila del dataframe 'combinaciones'

temperaturas_cab = []
temperaturas_ojos = []
temperaturas_piel = []

for e in combinaciones.CABELLO:
    if e in calidos:
        temperaturas_cab.append('calido')
    else:
        temperaturas_cab.append('frio')

for e in combinaciones.OJOS:
    if e in calidos:
        temperaturas_ojos.append('calido')
    else:
        temperaturas_ojos.append('frio')
        
for e in combinaciones.PIEL:
    if e in calidos:
        temperaturas_piel.append('calido')
    else:
        temperaturas_piel.append('frio')

# %%
#Definimos los casos de valores para cada fila del dataframe 'combinaciones'

valores_cab = []
valores_ojos = []
valores_piel = []

for e in combinaciones.CABELLO:
    if e in claro:
        valores_cab.append('claro')
    else:
        valores_cab.append('oscuro')
        
for e in combinaciones.OJOS:
    if e in claro:
        valores_ojos.append('claro')
    else:
        valores_ojos.append('oscuro')
        
for e in combinaciones.PIEL:
    if e in claro:
        valores_piel.append('claro')
    else:
        valores_piel.append('oscuro')

# %%
#Creamos las columnas e igualamos sus valores a las listas que hemos creado anteriormente.
combinaciones['TEMP_OJOS'] = temperaturas_ojos
combinaciones['TEMP_PIEL'] = temperaturas_piel
combinaciones['TEMP_CAB'] = temperaturas_cab
combinaciones['VALOR_CAB'] = valores_cab
combinaciones['VALOR_OJOS'] = valores_ojos
combinaciones['VALOR_PIEL'] = valores_piel

# %%
len(combinaciones)
# Out:
# 4480

# %% [markdown]
# Ahora, debemos diferenciar las diferentes paletas de colores que tendremos. Estas son:
#
#    1. **PRIMAVERA** - CÁLIDA, CLARA, BRILLANTE
#
#    2. **OTOÑO** - FRÍO, CLARO, SUAVE
#
#    3. **VERANO** - CÁLIDO, OSCURO, BRILLANTE
#
#    4. **INVIERNO** - FRÍO, OSCURO, BRILLANTE

# %%
#Determinamos si el total de cada fila es cálido o frío para poder asignar su paleta
temp = []
for i in combinaciones.index:
    if combinaciones['TEMP_CAB'][i] == 'calido' and ((combinaciones['TEMP_OJOS'][i] == 'calido') or \
                                                     (combinaciones['TEMP_PIEL'][i] == 'calido')):\
        temp.append('calido')
    elif str(combinaciones['TEMP_CAB'][i]) == 'frio' and ((combinaciones['TEMP_OJOS'][i]  == 'frio') or\
                                                     (combinaciones['TEMP_PIEL'][i]  == 'frio')):\
       
        temp.append('frio')
    elif combinaciones['TEMP_OJOS'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'calido' or \
                                                       combinaciones['TEMP_PIEL'][i] == 'calido'):\
        
        temp.append('calido')
    elif combinaciones['TEMP_OJOS'][i] == 'frio' and (combinaciones['TEMP_CAB'][i] == 'frio' or\
                                                      combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')
    elif combinaciones['TEMP_PIEL'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'calido' or\
                                                        combinaciones['TEMP_OJOS'][i] == 'calido'):\
        
        temp.append('calido')
    elif combinaciones['TEMP_PIEL'][i] == 'frio' and (combinaciones['TEMP_OJOS'][i] == 'frio' or\
                                                      combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')

    elif combinaciones['TEMP_OJOS'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'frio' and\
                                                        combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')
    else:
        temp.append('no')

combinaciones['TEMP_TOTAL'] = temp

# %%
#Determinamos si el total de cada fila es claro u oscuro para poder asignar su paleta
val = []
for i in combinaciones.index:
    if combinaciones['VALOR_CAB'][i] == 'claro' and ((combinaciones['VALOR_OJOS'][i] == 'claro') or \
                                                     (combinaciones['VALOR_PIEL'][i] == 'claro')):\
        val.append('claro')
    elif str(combinaciones['VALOR_CAB'][i]) == 'oscuro' and ((combinaciones['VALOR_OJOS'][i]  == 'oscuro') or\
                                                     (combinaciones['VALOR_PIEL'][i]  == 'oscuro')):\
       
        val.append('oscuro')
    elif combinaciones['VALOR_OJOS'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'claro' or \
                                                       combinaciones['VALOR_PIEL'][i] == 'claro'):\
        
        val.append('claro')
    elif combinaciones['VALOR_OJOS'][i] == 'oscuro' and (combinaciones['VALOR_CAB'][i] == 'oscuro' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')
    elif combinaciones['VALOR_PIEL'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'claro' or\
                                                        combinaciones['VALOR_OJOS'][i] == 'claro'):\
        
        val.append('claro')
    elif combinaciones['VALOR_PIEL'][i] == 'oscuro' and (combinaciones['VALOR_OJOS'][i] == 'oscuro' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')

    elif combinaciones['VALOR_OJOS'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'oscuro' and\
                                                        combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')
    else:
        val.append('no')

combinaciones['VALOR_TOTAL'] = val

# %%
#Determinamos si el total de cada fila es suave o brillante para poder asignar su paleta
cr = []
for i in combinaciones.index:
    if combinaciones['CROMA_CAB'][i] == 'brillante' and ((combinaciones['CROMA_OJOS'][i] == 'brillante') or \
                                                     (combinaciones['CROMA_PIEL'][i] == 'brillante')):\
        cr.append('brillante')
    elif str(combinaciones['CROMA_CAB'][i]) == 'suave' and ((combinaciones['CROMA_OJOS'][i]  == 'suave') or\
                                                     (combinaciones['CROMA_PIEL'][i]  == 'suave')):\
       
        cr.append('suave')
    elif combinaciones['CROMA_OJOS'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'brillante' or \
                                                       combinaciones['CROMA_PIEL'][i] == 'brillante'):\
        
        cr.append('brillante')
    elif combinaciones['CROMA_OJOS'][i] == 'suave' and (combinaciones['CROMA_CAB'][i] == 'suave' or\
                                                      combinaciones['CROMA_PIEL'][i] == 'suave'):\
        
        cr.append('suave')
    elif combinaciones['CROMA_PIEL'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'brillante' or\
                                                        combinaciones['CROMA_OJOS'][i] == 'brillante'):\
        
        cr.append('brillante')
    elif combinaciones['CROMA_PIEL'][i] == 'suave' and (combinaciones['CROMA_OJOS'][i] == 'suave' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'suave'):\
        
        cr.append('suave')

    elif combinaciones['CROMA_OJOS'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'suave' and\
                                                        combinaciones['CROMA_PIEL'][i] == 'suave'):\
        
        cr.append('suave')
    else:
        cr.append('no')


combinaciones['CROMA_TOTAL'] = cr

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL TEMP_OJOS  \
# 0   rubio  gris  melocoton      suave      suave      suave      frío
# 1   rubio  gris  melocoton      suave      suave  brillante      frío
# 2   rubio  gris  melocoton      suave  brillante      suave      frío
# 3   rubio  gris  melocoton      suave  brillante  brillante      frío
# 4   rubio  gris  melocoton  brillante      suave      suave      frío
#
#   TEMP_PIEL TEMP_CAB VALOR_CAB VALOR_OJOS VALOR_PIEL TEMP_TOTAL VALOR_TOTAL  \
# 0      frío   cálido     claro      claro     oscuro       frío       claro
# 1      frío   cálido     claro      claro     oscuro       frío       claro
# 2      frío   cálido     claro      claro     oscuro       frío       claro
# 3      frío   cálido     claro      claro     oscuro       frío       claro
# 4      frío   cálido     claro      claro     oscuro       frío       claro
#
#   CROMA_TOTAL
# 0       suave
# 1       suave
# 2       suave
# 3   brillante
# 4       suave

# %% [markdown]
# Ahora, debemos asignar las paletas de colores. Para ello, crearemos la columna 'PALETA'

# %%
#Vamos a crear listas que contengan la temperatura, valor y croma de cada paleta.
prim = ['calido', 'claro', 'brillante']
oto = ['frio', 'claro', 'suave']
ver = ['calido', 'oscuro', 'brillante']
inv = ['frio', 'oscuro', 'brillante']

# %%
#Ahora, en función de los valores por cada columna, debemos asignar la paleta PRIMAVERA, OTOÑO, INVIERNO o VERANO.
paletas = []

for i in combinaciones.index:

    if (combinaciones['TEMP_TOTAL'][i] in prim) and (combinaciones['VALOR_TOTAL'][i] in prim\
                                                     or combinaciones['CROMA_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')

    elif (combinaciones['TEMP_TOTAL'][i] in oto) and (combinaciones['VALOR_TOTAL'][i] in oto\
                                                      or combinaciones['CROMA_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')
        
    elif (combinaciones['TEMP_TOTAL'][i] in ver) and (combinaciones['VALOR_TOTAL'][i] in ver\
                                                     or combinaciones['CROMA_TOTAL'][i] in ver):\
        paletas.append('VERANO')

    elif (combinaciones['TEMP_TOTAL'][i] in inv) and (combinaciones['VALOR_TOTAL'][i] in inv\
                                                     or combinaciones['CROMA_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
        
    elif (combinaciones['VALOR_TOTAL'][i] in oto) and (combinaciones['TEMP_TOTAL'][i] in oto\
                                                     or combinaciones['CROMA_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')

    elif (combinaciones['VALOR_TOTAL'][i] in ver) and (combinaciones['TEMP_TOTAL'][i] in ver\
                                                     or combinaciones['CROMA_TOTAL'][i] in ver):\
        paletas.append('VERANO')
        
    elif (combinaciones['VALOR_TOTAL'][i] in prim) and (combinaciones['TEMP_TOTAL'][i] in prim\
                                                     or combinaciones['CROMA_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')
        
    elif (combinaciones['VALOR_TOTAL'][i] in inv) and (combinaciones['TEMP_TOTAL'][i] in inv\
                                                     or combinaciones['CROMA_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in prim) and (combinaciones['TEMP_TOTAL'][i] in prim\
                                                     or combinaciones['VALOR_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')
        
    elif (combinaciones['CROMA_TOTAL'][i] in oto) and (combinaciones['VALOR_TOTAL'][i] in oto\
                                                     or combinaciones['TEMP_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in ver) and (combinaciones['VALOR_TOTAL'][i] in ver\
                                                     or combinaciones['TEMP_TOTAL'][i] in ver):\
        paletas.append('VERANO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in inv) and (combinaciones['TEMP_TOTAL'][i] in inv\
                                                     or combinaciones['VALOR_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
    else:
        paletas.append('no')

# %%
combinaciones['PALETAS'] = paletas

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL TEMP_OJOS  \
# 0   rubio  gris  melocoton      suave      suave      suave      frío
# 1   rubio  gris  melocoton      suave      suave  brillante      frío
# 2   rubio  gris  melocoton      suave  brillante      suave      frío
# 3   rubio  gris  melocoton      suave  brillante  brillante      frío
# 4   rubio  gris  melocoton  brillante      suave      suave      frío
#
#   TEMP_PIEL TEMP_CAB VALOR_CAB VALOR_OJOS VALOR_PIEL TEMP_TOTAL VALOR_TOTAL  \
# 0      frío   cálido     claro      claro     oscuro       frío       claro
# 1      frío   cálido     claro      claro     oscuro       frío       claro
# 2      frío   cálido     claro      claro     oscuro       frío       claro
# 3      frío   cálido     claro      claro     oscuro       frío       claro
# 4      frío   cálido     claro      claro     oscuro       frío       claro
#
#   CROMA_TOTAL PALETAS
# 0       suave   OTOÑO
# 1       suave   OTOÑO
# 2       suave   OTOÑO
# 3   brillante   OTOÑO
# 4       suave   OTOÑO

# %%
#Volvemos a poner las 'ñ' a las palabras ya que en SQL hemos tenido que borrarlas porque el programa no lo cogía
def quitar_n(columna):
    if columna == 'castano':
        return 'castaño'
    elif columna == 'castano claro':
        return 'castaño claro'
    elif columna == 'castano oscuro':
        return 'castaño oscuro'
    else:
        return columna

# %%
combinaciones.CABELLO = combinaciones.CABELLO.apply(quitar_n)

# %%
columna = [e for e in range(len(combinaciones))]

# %%
combinaciones['ID'] = columna

# %%
#Añadimos un ID como indice 
combinaciones.set_index('ID', drop = True, inplace = True)

# %%
#Cambiamos de tipo de dato
combinaciones[['CABELLO', 'OJOS', 'PIEL', 'CROMA_CAB', 'CROMA_OJOS',\
                  'CROMA_PIEL', 'TEMP_OJOS', 'TEMP_PIEL', 'TEMP_CAB',\
                  'VALOR_CAB', 'VALOR_OJOS', 'VALOR_PIEL', 'TEMP_TOTAL',\
                  'VALOR_TOTAL', 'CROMA_TOTAL', 'PALETAS']] =\
combinaciones[['CABELLO', 'OJOS', 'PIEL', 'CROMA_CAB', 'CROMA_OJOS',\
                  'CROMA_PIEL', 'TEMP_OJOS', 'TEMP_PIEL', 'TEMP_CAB',\
                  'VALOR_CAB', 'VALOR_OJOS', 'VALOR_PIEL', 'TEMP_TOTAL',\
                  'VALOR_TOTAL', 'CROMA_TOTAL', 'PALETAS']].astype('category')

# %%
combinaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4480 entries, 0 to 4479
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CABELLO      4480 non-null   category
#  1   OJOS         4480 non-null   category
#  2   PIEL         4480 non-null   category
#  3   CROMA_CAB    4480 non-null   category
#  4   CROMA_OJOS   4480 non-null   category
#  5   CROMA_PIEL   4480 non-null   category
#  6   TEMP_OJOS    4480 non-null   category
#  7   TEMP_PIEL    4480 non-null   category
#  8   TEMP_CAB     4480 non-null   category
#  9   VALOR_CAB    4480 non-null   category
#  10  VALOR_OJOS   4480 non-null   category
#  11  VALOR_PIEL   4480 non-null   category
#  12  TEMP_TOTAL   4480 non-null   category
#  13  VALOR_TOTAL  4480 non-null   category
#  14  CROMA_TOTAL  4480 non-null   category
#  15  PALETAS      4480 non-null   category
# dtypes: category(16)
# memory usage: 107.7 KB

# %%
combinaciones.to_csv('../TABLA_BASE/combinaciones_final_csv.csv')

# %%
combinaciones
# Out:
#              CABELLO           OJOS                   PIEL  CROMA_CAB  \
# ID
# 0              rubio           gris              melocoton      suave
# 1              rubio           gris              melocoton      suave
# 2              rubio           gris              melocoton      suave
# 3              rubio           gris              melocoton      suave
# 4              rubio           gris              melocoton  brillante
# 5              rubio           gris              melocoton  brillante
# 6              rubio           gris              melocoton  brillante
# 7              rubio           gris              melocoton  brillante
# 8              rubio           gris        blanco / palido      suave
# 9              rubio           gris        blanco / palido      suave
# 10             rubio           gris        blanco / palido      suave
# 11             rubio           gris        blanco / palido      suave
# 12             rubio           gris        blanco / palido  brillante
# 13             rubio           gris        blanco / palido  brillante
# 14             rubio           gris        blanco / palido  brillante
# 15             rubio           gris        blanco / palido  brillante
# 16             rubio           gris                 rosada      suave
# 17             rubio           gris                 rosada      suave
# 18             rubio           gris                 rosada      suave
# 19             rubio           gris                 rosada      suave
# 20             rubio           gris                 rosada  brillante
# 21             rubio           gris                 rosada  brillante
# 22             rubio           gris                 rosada  brillante
# 23             rubio           gris                 rosada  brillante
# 24             rubio           gris                  negro      suave
# 25             rubio           gris                  negro      suave
# 26             rubio           gris                  negro      suave
# 27             rubio           gris                  negro      suave
# 28             rubio           gris                  negro  brillante
# 29             rubio           gris                  negro  brillante
# 30             rubio           gris                  negro  brillante
# 31             rubio           gris                  negro  brillante
# 32             rubio           gris            amarillento      suave
# 33             rubio           gris            amarillento      suave
# 34             rubio           gris            amarillento      suave
# 35             rubio           gris            amarillento      suave
# 36             rubio           gris            amarillento  brillante
# 37             rubio           gris            amarillento  brillante
# 38             rubio           gris            amarillento  brillante
# 39             rubio           gris            amarillento  brillante
# 40             rubio           gris  moreno claro / dorado      suave
# 41             rubio           gris  moreno claro / dorado      suave
# 42             rubio           gris  moreno claro / dorado      suave
# 43             rubio           gris  moreno claro / dorado      suave
# 44             rubio           gris  moreno claro / dorado  brillante
# 45             rubio           gris  moreno claro / dorado  brillante
# 46             rubio           gris  moreno claro / dorado  brillante
# 47             rubio           gris  moreno claro / dorado  brillante
# 48             rubio           gris  moreno / marron claro      suave
# 49             rubio           gris  moreno / marron claro      suave
# 50             rubio           gris  moreno / marron claro      suave
# 51             rubio           gris  moreno / marron claro      suave
# 52             rubio           gris  moreno / marron claro  brillante
# 53             rubio           gris  moreno / marron claro  brillante
# 54             rubio           gris  moreno / marron claro  brillante
# 55             rubio           gris  moreno / marron claro  brillante
# 56             rubio          negro              melocoton      suave
# 57             rubio          negro              melocoton      suave
# 58             rubio          negro              melocoton      suave
# 59             rubio          negro              melocoton      suave
# 60             rubio          negro              melocoton  brillante
# 61             rubio          negro              melocoton  brillante
# 62             rubio          negro              melocoton  brillante
# 63             rubio          negro              melocoton  brillante
# 64             rubio          negro        blanco / palido      suave
# 65             rubio          negro        blanco / palido      suave
# 66             rubio          negro        blanco / palido      suave
# 67             rubio          negro        blanco / palido      suave
# 68             rubio          negro        blanco / palido  brillante
# 69             rubio          negro        blanco / palido  brillante
# 70             rubio          negro        blanco / palido  brillante
# 71             rubio          negro        blanco / palido  brillante
# 72             rubio          negro                 rosada      suave
# 73             rubio          negro                 rosada      suave
# 74             rubio          negro                 rosada      suave
# 75             rubio          negro                 rosada      suave
# 76             rubio          negro                 rosada  brillante
# 77             rubio          negro                 rosada  brillante
# 78             rubio          negro                 rosada  brillante
# 79             rubio          negro                 rosada  brillante
# 80             rubio          negro                  negro      suave
# 81             rubio          negro                  negro      suave
# 82             rubio          negro                  negro      suave
# 83             rubio          negro                  negro      suave
# 84             rubio          negro                  negro  brillante
# 85             rubio          negro                  negro  brillante
# 86             rubio          negro                  negro  brillante
# 87             rubio          negro                  negro  brillante
# 88             rubio          negro            amarillento      suave
# 89             rubio          negro            amarillento      suave
# 90             rubio          negro            amarillento      suave
# 91             rubio          negro            amarillento      suave
# 92             rubio          negro            amarillento  brillante
# 93             rubio          negro            amarillento  brillante
# 94             rubio          negro            amarillento  brillante
# 95             rubio          negro            amarillento  brillante
# 96             rubio          negro  moreno claro / dorado      suave
# 97             rubio          negro  moreno claro / dorado      suave
# 98             rubio          negro  moreno claro / dorado      suave
# 99             rubio          negro  moreno claro / dorado      suave
# 100            rubio          negro  moreno claro / dorado  brillante
# 101            rubio          negro  moreno claro / dorado  brillante
# 102            rubio          negro  moreno claro / dorado  brillante
# 103            rubio          negro  moreno claro / dorado  brillante
# 104            rubio          negro  moreno / marron claro      suave
# 105            rubio          negro  moreno / marron claro      suave
# 106            rubio          negro  moreno / marron claro      suave
# 107            rubio          negro  moreno / marron claro      suave
# 108            rubio          negro  moreno / marron claro  brillante
# 109            rubio          negro  moreno / marron claro  brillante
# 110            rubio          negro  moreno / marron claro  brillante
# 111            rubio          negro  moreno / marron claro  brillante
# 112            rubio  marron oscuro              melocoton      suave
# 113            rubio  marron oscuro              melocoton      suave
# 114            rubio  marron oscuro              melocoton      suave
# 115            rubio  marron oscuro              melocoton      suave
# 116            rubio  marron oscuro              melocoton  brillante
# 117            rubio  marron oscuro              melocoton  brillante
# 118            rubio  marron oscuro              melocoton  brillante
# 119            rubio  marron oscuro              melocoton  brillante
# 120            rubio  marron oscuro        blanco / palido      suave
# 121            rubio  marron oscuro        blanco / palido      suave
# 122            rubio  marron oscuro        blanco / palido      suave
# 123            rubio  marron oscuro        blanco / palido      suave
# 124            rubio  marron oscuro        blanco / palido  brillante
# 125            rubio  marron oscuro        blanco / palido  brillante
# 126            rubio  marron oscuro        blanco / palido  brillante
# 127            rubio  marron oscuro        blanco / palido  brillante
# 128            rubio  marron oscuro                 rosada      suave
# 129            rubio  marron oscuro                 rosada      suave
# 130            rubio  marron oscuro                 rosada      suave
# 131            rubio  marron oscuro                 rosada      suave
# 132            rubio  marron oscuro                 rosada  brillante
# 133            rubio  marron oscuro                 rosada  brillante
# 134            rubio  marron oscuro                 rosada  brillante
# 135            rubio  marron oscuro                 rosada  brillante
# 136            rubio  marron oscuro                  negro      suave
# 137            rubio  marron oscuro                  negro      suave
# 138            rubio  marron oscuro                  negro      suave
# 139            rubio  marron oscuro                  negro      suave
# 140            rubio  marron oscuro                  negro  brillante
# 141            rubio  marron oscuro                  negro  brillante
# 142            rubio  marron oscuro                  negro  brillante
# 143            rubio  marron oscuro                  negro  brillante
# 144            rubio  marron oscuro            amarillento      suave
# 145            rubio  marron oscuro            amarillento      suave
# 146            rubio  marron oscuro            amarillento      suave
# 147            rubio  marron oscuro            amarillento      suave
# 148            rubio  marron oscuro            amarillento  brillante
# 149            rubio  marron oscuro            amarillento  brillante
# 150            rubio  marron oscuro            amarillento  brillante
# 151            rubio  marron oscuro            amarillento  brillante
# 152            rubio  marron oscuro  moreno claro / dorado      suave
# 153            rubio  marron oscuro  moreno claro / dorado      suave
# 154            rubio  marron oscuro  moreno claro / dorado      suave
# 155            rubio  marron oscuro  moreno claro / dorado      suave
# 156            rubio  marron oscuro  moreno claro / dorado  brillante
# 157            rubio  marron oscuro  moreno claro / dorado  brillante
# 158            rubio  marron oscuro  moreno claro / dorado  brillante
# 159            rubio  marron oscuro  moreno claro / dorado  brillante
# 160            rubio  marron oscuro  moreno / marron claro      suave
# 161            rubio  marron oscuro  moreno / marron claro      suave
# 162            rubio  marron oscuro  moreno / marron claro      suave
# 163            rubio  marron oscuro  moreno / marron claro      suave
# 164            rubio  marron oscuro  moreno / marron claro  brillante
# 165            rubio  marron oscuro  moreno / marron claro  brillante
# 166            rubio  marron oscuro  moreno / marron claro  brillante
# 167            rubio  marron oscuro  moreno / marron claro  brillante
# 168            rubio           azul              melocoton      suave
# 169            rubio           azul              melocoton      suave
# 170            rubio           azul              melocoton      suave
# 171            rubio           azul              melocoton      suave
# 172            rubio           azul              melocoton  brillante
# 173            rubio           azul              melocoton  brillante
# 174            rubio           azul              melocoton  brillante
# 175            rubio           azul              melocoton  brillante
# 176            rubio           azul        blanco / palido      suave
# 177            rubio           azul        blanco / palido      suave
# 178            rubio           azul        blanco / palido      suave
# 179            rubio           azul        blanco / palido      suave
# 180            rubio           azul        blanco / palido  brillante
# 181            rubio           azul        blanco / palido  brillante
# 182            rubio           azul        blanco / palido  brillante
# 183            rubio           azul        blanco / palido  brillante
# 184            rubio           azul                 rosada      suave
# 185            rubio           azul                 rosada      suave
# 186            rubio           azul                 rosada      suave
# 187            rubio           azul                 rosada      suave
# 188            rubio           azul                 rosada  brillante
# 189            rubio           azul                 rosada  brillante
# 190            rubio           azul                 rosada  brillante
# 191            rubio           azul                 rosada  brillante
# 192            rubio           azul                  negro      suave
# 193            rubio           azul                  negro      suave
# 194            rubio           azul                  negro      suave
# 195            rubio           azul                  negro      suave
# 196            rubio           azul                  negro  brillante
# 197            rubio           azul                  negro  brillante
# 198            rubio           azul                  negro  brillante
# 199            rubio           azul                  negro  brillante
# 200            rubio           azul            amarillento      suave
# 201            rubio           azul            amarillento      suave
# 202            rubio           azul            amarillento      suave
# 203            rubio           azul            amarillento      suave
# 204            rubio           azul            amarillento  brillante
# 205            rubio           azul            amarillento  brillante
# 206            rubio           azul            amarillento  brillante
# 207            rubio           azul            amarillento  brillante
# 208            rubio           azul  moreno claro / dorado      suave
# 209            rubio           azul  moreno claro / dorado      suave
# 210            rubio           azul  moreno claro / dorado      suave
# 211            rubio           azul  moreno claro / dorado      suave
# 212            rubio           azul  moreno claro / dorado  brillante
# 213            rubio           azul  moreno claro / dorado  brillante
# 214            rubio           azul  moreno claro / dorado  brillante
# 215            rubio           azul  moreno claro / dorado  brillante
# 216            rubio           azul  moreno / marron claro      suave
# 217            rubio           azul  moreno / marron claro      suave
# 218            rubio           azul  moreno / marron claro      suave
# 219            rubio           azul  moreno / marron claro      suave
# 220            rubio           azul  moreno / marron claro  brillante
# 221            rubio           azul  moreno / marron claro  brillante
# 222            rubio           azul  moreno / marron claro  brillante
# 223            rubio           azul  moreno / marron claro  brillante
# 224            rubio       almendra              melocoton      suave
# 225            rubio       almendra              melocoton      suave
# 226            rubio       almendra              melocoton      suave
# 227            rubio       almendra              melocoton      suave
# 228            rubio       almendra              melocoton  brillante
# 229            rubio       almendra              melocoton  brillante
# 230            rubio       almendra              melocoton  brillante
# 231            rubio       almendra              melocoton  brillante
# 232            rubio       almendra        blanco / palido      suave
# 233            rubio       almendra        blanco / palido      suave
# 234            rubio       almendra        blanco / palido      suave
# 235            rubio       almendra        blanco / palido      suave
# 236            rubio       almendra        blanco / palido  brillante
# 237            rubio       almendra        blanco / palido  brillante
# 238            rubio       almendra        blanco / palido  brillante
# 239            rubio       almendra        blanco / palido  brillante
# 240            rubio       almendra                 rosada      suave
# 241            rubio       almendra                 rosada      suave
# 242            rubio       almendra                 rosada      suave
# 243            rubio       almendra                 rosada      suave
# 244            rubio       almendra                 rosada  brillante
# 245            rubio       almendra                 rosada  brillante
# 246            rubio       almendra                 rosada  brillante
# 247            rubio       almendra                 rosada  brillante
# 248            rubio       almendra                  negro      suave
# 249            rubio       almendra                  negro      suave
# 250            rubio       almendra                  negro      suave
# 251            rubio       almendra                  negro      suave
# 252            rubio       almendra                  negro  brillante
# 253            rubio       almendra                  negro  brillante
# 254            rubio       almendra                  negro  brillante
# 255            rubio       almendra                  negro  brillante
# 256            rubio       almendra            amarillento      suave
# 257            rubio       almendra            amarillento      suave
# 258            rubio       almendra            amarillento      suave
# 259            rubio       almendra            amarillento      suave
# 260            rubio       almendra            amarillento  brillante
# 261            rubio       almendra            amarillento  brillante
# 262            rubio       almendra            amarillento  brillante
# 263            rubio       almendra            amarillento  brillante
# 264            rubio       almendra  moreno claro / dorado      suave
# 265            rubio       almendra  moreno claro / dorado      suave
# 266            rubio       almendra  moreno claro / dorado      suave
# 267            rubio       almendra  moreno claro / dorado      suave
# 268            rubio       almendra  moreno claro / dorado  brillante
# 269            rubio       almendra  moreno claro / dorado  brillante
# 270            rubio       almendra  moreno claro / dorado  brillante
# 271            rubio       almendra  moreno claro / dorado  brillante
# 272            rubio       almendra  moreno / marron claro      suave
# 273            rubio       almendra  moreno / marron claro      suave
# 274            rubio       almendra  moreno / marron claro      suave
# 275            rubio       almendra  moreno / marron claro      suave
# 276            rubio       almendra  moreno / marron claro  brillante
# 277            rubio       almendra  moreno / marron claro  brillante
# 278            rubio       almendra  moreno / marron claro  brillante
# 279            rubio       almendra  moreno / marron claro  brillante
# 280            rubio          ambar              melocoton      suave
# 281            rubio          ambar              melocoton      suave
# 282            rubio          ambar              melocoton      suave
# 283            rubio          ambar              melocoton      suave
# 284            rubio          ambar              melocoton  brillante
# 285            rubio          ambar              melocoton  brillante
# 286            rubio          ambar              melocoton  brillante
# 287            rubio          ambar              melocoton  brillante
# 288            rubio          ambar        blanco / palido      suave
# 289            rubio          ambar        blanco / palido      suave
# 290            rubio          ambar        blanco / palido      suave
# 291            rubio          ambar        blanco / palido      suave
# 292            rubio          ambar        blanco / palido  brillante
# 293            rubio          ambar        blanco / palido  brillante
# 294            rubio          ambar        blanco / palido  brillante
# 295            rubio          ambar        blanco / palido  brillante
# 296            rubio          ambar                 rosada      suave
# 297            rubio          ambar                 rosada      suave
# 298            rubio          ambar                 rosada      suave
# 299            rubio          ambar                 rosada      suave
# 300            rubio          ambar                 rosada  brillante
# 301            rubio          ambar                 rosada  brillante
# 302            rubio          ambar                 rosada  brillante
# 303            rubio          ambar                 rosada  brillante
# 304            rubio          ambar                  negro      suave
# 305            rubio          ambar                  negro      suave
# 306            rubio          ambar                  negro      suave
# 307            rubio          ambar                  negro      suave
# 308            rubio          ambar                  negro  brillante
# 309            rubio          ambar                  negro  brillante
# 310            rubio          ambar                  negro  brillante
# 311            rubio          ambar                  negro  brillante
# 312            rubio          ambar            amarillento      suave
# 313            rubio          ambar            amarillento      suave
# 314            rubio          ambar            amarillento      suave
# 315            rubio          ambar            amarillento      suave
# 316            rubio          ambar            amarillento  brillante
# 317            rubio          ambar            amarillento  brillante
# 318            rubio          ambar            amarillento  brillante
# 319            rubio          ambar            amarillento  brillante
# 320            rubio          ambar  moreno claro / dorado      suave
# 321            rubio          ambar  moreno claro / dorado      suave
# 322            rubio          ambar  moreno claro / dorado      suave
# 323            rubio          ambar  moreno claro / dorado      suave
# 324            rubio          ambar  moreno claro / dorado  brillante
# 325            rubio          ambar  moreno claro / dorado  brillante
# 326            rubio          ambar  moreno claro / dorado  brillante
# 327            rubio          ambar  moreno claro / dorado  brillante
# 328            rubio          ambar  moreno / marron claro      suave
# 329            rubio          ambar  moreno / marron claro      suave
# 330            rubio          ambar  moreno / marron claro      suave
# 331            rubio          ambar  moreno / marron claro      suave
# 332            rubio          ambar  moreno / marron claro  brillante
# 333            rubio          ambar  moreno / marron claro  brillante
# 334            rubio          ambar  moreno / marron claro  brillante
# 335            rubio          ambar  moreno / marron claro  brillante
# 336            rubio          verde              melocoton      suave
# 337            rubio          verde              melocoton      suave
# 338            rubio          verde              melocoton      suave
# 339            rubio          verde              melocoton      suave
# 340            rubio          verde              melocoton  brillante
# 341            rubio          verde              melocoton  brillante
# 342            rubio          verde              melocoton  brillante
# 343            rubio          verde              melocoton  brillante
# 344            rubio          verde        blanco / palido      suave
# 345            rubio          verde        blanco / palido      suave
# 346            rubio          verde        blanco / palido      suave
# 347            rubio          verde        blanco / palido      suave
# 348            rubio          verde        blanco / palido  brillante
# 349            rubio          verde        blanco / palido  brillante
# 350            rubio          verde        blanco / palido  brillante
# 351            rubio          verde        blanco / palido  brillante
# 352            rubio          verde                 rosada      suave
# 353            rubio          verde                 rosada      suave
# 354            rubio          verde                 rosada      suave
# 355            rubio          verde                 rosada      suave
# 356            rubio          verde                 rosada  brillante
# 357            rubio          verde                 rosada  brillante
# 358            rubio          verde                 rosada  brillante
# 359            rubio          verde                 rosada  brillante
# 360            rubio          verde                  negro      suave
# 361            rubio          verde                  negro      suave
# 362            rubio          verde                  negro      suave
# 363            rubio          verde                  negro      suave
# 364            rubio          verde                  negro  brillante
# 365            rubio          verde                  negro  brillante
# 366            rubio          verde                  negro  brillante
# 367            rubio          verde                  negro  brillante
# 368            rubio          verde            amarillento      suave
# 369            rubio          verde            amarillento      suave
# 370            rubio          verde            amarillento      suave
# 371            rubio          verde            amarillento      suave
# 372            rubio          verde            amarillento  brillante
# 373            rubio          verde            amarillento  brillante
# 374            rubio          verde            amarillento  brillante
# 375            rubio          verde            amarillento  brillante
# 376            rubio          verde  moreno claro / dorado      suave
# 377            rubio          verde  moreno claro / dorado      suave
# 378            rubio          verde  moreno claro / dorado      suave
# 379            rubio          verde  moreno claro / dorado      suave
# 380            rubio          verde  moreno claro / dorado  brillante
# 381            rubio          verde  moreno claro / dorado  brillante
# 382            rubio          verde  moreno claro / dorado  brillante
# 383            rubio          verde  moreno claro / dorado  brillante
# 384            rubio          verde  moreno / marron claro      suave
# 385            rubio          verde  moreno / marron claro      suave
# 386            rubio          verde  moreno / marron claro      suave
# 387            rubio          verde  moreno / marron claro      suave
# 388            rubio          verde  moreno / marron claro  brillante
# 389            rubio          verde  moreno / marron claro  brillante
# 390            rubio          verde  moreno / marron claro  brillante
# 391            rubio          verde  moreno / marron claro  brillante
# 392            rubio           miel              melocoton      suave
# 393            rubio           miel              melocoton      suave
# 394            rubio           miel              melocoton      suave
# 395            rubio           miel              melocoton      suave
# 396            rubio           miel              melocoton  brillante
# 397            rubio           miel              melocoton  brillante
# 398            rubio           miel              melocoton  brillante
# 399            rubio           miel              melocoton  brillante
# 400            rubio           miel        blanco / palido      suave
# 401            rubio           miel        blanco / palido      suave
# 402            rubio           miel        blanco / palido      suave
# 403            rubio           miel        blanco / palido      suave
# 404            rubio           miel        blanco / palido  brillante
# 405            rubio           miel        blanco / palido  brillante
# 406            rubio           miel        blanco / palido  brillante
# 407            rubio           miel        blanco / palido  brillante
# 408            rubio           miel                 rosada      suave
# 409            rubio           miel                 rosada      suave
# 410            rubio           miel                 rosada      suave
# 411            rubio           miel                 rosada      suave
# 412            rubio           miel                 rosada  brillante
# 413            rubio           miel                 rosada  brillante
# 414            rubio           miel                 rosada  brillante
# 415            rubio           miel                 rosada  brillante
# 416            rubio           miel                  negro      suave
# 417            rubio           miel                  negro      suave
# 418            rubio           miel                  negro      suave
# 419            rubio           miel                  negro      suave
# 420            rubio           miel                  negro  brillante
# 421            rubio           miel                  negro  brillante
# 422            rubio           miel                  negro  brillante
# 423            rubio           miel                  negro  brillante
# 424            rubio           miel            amarillento      suave
# 425            rubio           miel            amarillento      suave
# 426            rubio           miel            amarillento      suave
# 427            rubio           miel            amarillento      suave
# 428            rubio           miel            amarillento  brillante
# 429            rubio           miel            amarillento  brillante
# 430            rubio           miel            amarillento  brillante
# 431            rubio           miel            amarillento  brillante
# 432            rubio           miel  moreno claro / dorado      suave
# 433            rubio           miel  moreno claro / dorado      suave
# 434            rubio           miel  moreno claro / dorado      suave
# 435            rubio           miel  moreno claro / dorado      suave
# 436            rubio           miel  moreno claro / dorado  brillante
# 437            rubio           miel  moreno claro / dorado  brillante
# 438            rubio           miel  moreno claro / dorado  brillante
# 439            rubio           miel  moreno claro / dorado  brillante
# 440            rubio           miel  moreno / marron claro      suave
# 441            rubio           miel  moreno / marron claro      suave
# 442            rubio           miel  moreno / marron claro      suave
# 443            rubio           miel  moreno / marron claro      suave
# 444            rubio           miel  moreno / marron claro  brillante
# 445            rubio           miel  moreno / marron claro  brillante
# 446            rubio           miel  moreno / marron claro  brillante
# 447            rubio           miel  moreno / marron claro  brillante
# 448     rubio ceniza           gris              melocoton      suave
# 449     rubio ceniza           gris              melocoton      suave
# 450     rubio ceniza           gris              melocoton      suave
# 451     rubio ceniza           gris              melocoton      suave
# 452     rubio ceniza           gris              melocoton  brillante
# 453     rubio ceniza           gris              melocoton  brillante
# 454     rubio ceniza           gris              melocoton  brillante
# 455     rubio ceniza           gris              melocoton  brillante
# 456     rubio ceniza           gris        blanco / palido      suave
# 457     rubio ceniza           gris        blanco / palido      suave
# 458     rubio ceniza           gris        blanco / palido      suave
# 459     rubio ceniza           gris        blanco / palido      suave
# 460     rubio ceniza           gris        blanco / palido  brillante
# 461     rubio ceniza           gris        blanco / palido  brillante
# 462     rubio ceniza           gris        blanco / palido  brillante
# 463     rubio ceniza           gris        blanco / palido  brillante
# 464     rubio ceniza           gris                 rosada      suave
# 465     rubio ceniza           gris                 rosada      suave
# 466     rubio ceniza           gris                 rosada      suave
# 467     rubio ceniza           gris                 rosada      suave
# 468     rubio ceniza           gris                 rosada  brillante
# 469     rubio ceniza           gris                 rosada  brillante
# 470     rubio ceniza           gris                 rosada  brillante
# 471     rubio ceniza           gris                 rosada  brillante
# 472     rubio ceniza           gris                  negro      suave
# 473     rubio ceniza           gris                  negro      suave
# 474     rubio ceniza           gris                  negro      suave
# 475     rubio ceniza           gris                  negro      suave
# 476     rubio ceniza           gris                  negro  brillante
# 477     rubio ceniza           gris                  negro  brillante
# 478     rubio ceniza           gris                  negro  brillante
# 479     rubio ceniza           gris                  negro  brillante
# 480     rubio ceniza           gris            amarillento      suave
# 481     rubio ceniza           gris            amarillento      suave
# 482     rubio ceniza           gris            amarillento      suave
# 483     rubio ceniza           gris            amarillento      suave
# 484     rubio ceniza           gris            amarillento  brillante
# 485     rubio ceniza           gris            amarillento  brillante
# 486     rubio ceniza           gris            amarillento  brillante
# 487     rubio ceniza           gris            amarillento  brillante
# 488     rubio ceniza           gris  moreno claro / dorado      suave
# 489     rubio ceniza           gris  moreno claro / dorado      suave
# 490     rubio ceniza           gris  moreno claro / dorado      suave
# 491     rubio ceniza           gris  moreno claro / dorado      suave
# 492     rubio ceniza           gris  moreno claro / dorado  brillante
# 493     rubio ceniza           gris  moreno claro / dorado  brillante
# 494     rubio ceniza           gris  moreno claro / dorado  brillante
# 495     rubio ceniza           gris  moreno claro / dorado  brillante
# 496     rubio ceniza           gris  moreno / marron claro      suave
# 497     rubio ceniza           gris  moreno / marron claro      suave
# 498     rubio ceniza           gris  moreno / marron claro      suave
# 499     rubio ceniza           gris  moreno / marron claro      suave
# 500     rubio ceniza           gris  moreno / marron claro  brillante
# 501     rubio ceniza           gris  moreno / marron claro  brillante
# 502     rubio ceniza           gris  moreno / marron claro  brillante
# 503     rubio ceniza           gris  moreno / marron claro  brillante
# 504     rubio ceniza          negro              melocoton      suave
# 505     rubio ceniza          negro              melocoton      suave
# 506     rubio ceniza          negro              melocoton      suave
# 507     rubio ceniza          negro              melocoton      suave
# 508     rubio ceniza          negro              melocoton  brillante
# 509     rubio ceniza          negro              melocoton  brillante
# 510     rubio ceniza          negro              melocoton  brillante
# 511     rubio ceniza          negro              melocoton  brillante
# 512     rubio ceniza          negro        blanco / palido      suave
# 513     rubio ceniza          negro        blanco / palido      suave
# 514     rubio ceniza          negro        blanco / palido      suave
# 515     rubio ceniza          negro        blanco / palido      suave
# 516     rubio ceniza          negro        blanco / palido  brillante
# 517     rubio ceniza          negro        blanco / palido  brillante
# 518     rubio ceniza          negro        blanco / palido  brillante
# 519     rubio ceniza          negro        blanco / palido  brillante
# 520     rubio ceniza          negro                 rosada      suave
# 521     rubio ceniza          negro                 rosada      suave
# 522     rubio ceniza          negro                 rosada      suave
# 523     rubio ceniza          negro                 rosada      suave
# 524     rubio ceniza          negro                 rosada  brillante
# 525     rubio ceniza          negro                 rosada  brillante
# 526     rubio ceniza          negro                 rosada  brillante
# 527     rubio ceniza          negro                 rosada  brillante
# 528     rubio ceniza          negro                  negro      suave
# 529     rubio ceniza          negro                  negro      suave
# 530     rubio ceniza          negro                  negro      suave
# 531     rubio ceniza          negro                  negro      suave
# 532     rubio ceniza          negro                  negro  brillante
# 533     rubio ceniza          negro                  negro  brillante
# 534     rubio ceniza          negro                  negro  brillante
# 535     rubio ceniza          negro                  negro  brillante
# 536     rubio ceniza          negro            amarillento      suave
# 537     rubio ceniza          negro            amarillento      suave
# 538     rubio ceniza          negro            amarillento      suave
# 539     rubio ceniza          negro            amarillento      suave
# 540     rubio ceniza          negro            amarillento  brillante
# 541     rubio ceniza          negro            amarillento  brillante
# 542     rubio ceniza          negro            amarillento  brillante
# 543     rubio ceniza          negro            amarillento  brillante
# 544     rubio ceniza          negro  moreno claro / dorado      suave
# 545     rubio ceniza          negro  moreno claro / dorado      suave
# 546     rubio ceniza          negro  moreno claro / dorado      suave
# 547     rubio ceniza          negro  moreno claro / dorado      suave
# 548     rubio ceniza          negro  moreno claro / dorado  brillante
# 549     rubio ceniza          negro  moreno claro / dorado  brillante
# 550     rubio ceniza          negro  moreno claro / dorado  brillante
# 551     rubio ceniza          negro  moreno claro / dorado  brillante
# 552     rubio ceniza          negro  moreno / marron claro      suave
# 553     rubio ceniza          negro  moreno / marron claro      suave
# 554     rubio ceniza          negro  moreno / marron claro      suave
# 555     rubio ceniza          negro  moreno / marron claro      suave
# 556     rubio ceniza          negro  moreno / marron claro  brillante
# 557     rubio ceniza          negro  moreno / marron claro  brillante
# 558     rubio ceniza          negro  moreno / marron claro  brillante
# 559     rubio ceniza          negro  moreno / marron claro  brillante
# 560     rubio ceniza  marron oscuro              melocoton      suave
# 561     rubio ceniza  marron oscuro              melocoton      suave
# 562     rubio ceniza  marron oscuro              melocoton      suave
# 563     rubio ceniza  marron oscuro              melocoton      suave
# 564     rubio ceniza  marron oscuro              melocoton  brillante
# 565     rubio ceniza  marron oscuro              melocoton  brillante
# 566     rubio ceniza  marron oscuro              melocoton  brillante
# 567     rubio ceniza  marron oscuro              melocoton  brillante
# 568     rubio ceniza  marron oscuro        blanco / palido      suave
# 569     rubio ceniza  marron oscuro        blanco / palido      suave
# 570     rubio ceniza  marron oscuro        blanco / palido      suave
# 571     rubio ceniza  marron oscuro        blanco / palido      suave
# 572     rubio ceniza  marron oscuro        blanco / palido  brillante
# 573     rubio ceniza  marron oscuro        blanco / palido  brillante
# 574     rubio ceniza  marron oscuro        blanco / palido  brillante
# 575     rubio ceniza  marron oscuro        blanco / palido  brillante
# 576     rubio ceniza  marron oscuro                 rosada      suave
# 577     rubio ceniza  marron oscuro                 rosada      suave
# 578     rubio ceniza  marron oscuro                 rosada      suave
# 579     rubio ceniza  marron oscuro                 rosada      suave
# 580     rubio ceniza  marron oscuro                 rosada  brillante
# 581     rubio ceniza  marron oscuro                 rosada  brillante
# 582     rubio ceniza  marron oscuro                 rosada  brillante
# 583     rubio ceniza  marron oscuro                 rosada  brillante
# 584     rubio ceniza  marron oscuro                  negro      suave
# 585     rubio ceniza  marron oscuro                  negro      suave
# 586     rubio ceniza  marron oscuro                  negro      suave
# 587     rubio ceniza  marron oscuro                  negro      suave
# 588     rubio ceniza  marron oscuro                  negro  brillante
# 589     rubio ceniza  marron oscuro                  negro  brillante
# 590     rubio ceniza  marron oscuro                  negro  brillante
# 591     rubio ceniza  marron oscuro                  negro  brillante
# 592     rubio ceniza  marron oscuro            amarillento      suave
# 593     rubio ceniza  marron oscuro            amarillento      suave
# 594     rubio ceniza  marron oscuro            amarillento      suave
# 595     rubio ceniza  marron oscuro            amarillento      suave
# 596     rubio ceniza  marron oscuro            amarillento  brillante
# 597     rubio ceniza  marron oscuro            amarillento  brillante
# 598     rubio ceniza  marron oscuro            amarillento  brillante
# 599     rubio ceniza  marron oscuro            amarillento  brillante
# 600     rubio ceniza  marron oscuro  moreno claro / dorado      suave
# 601     rubio ceniza  marron oscuro  moreno claro / dorado      suave
# 602     rubio ceniza  marron oscuro  moreno claro / dorado      suave
# 603     rubio ceniza  marron oscuro  moreno claro / dorado      suave
# 604     rubio ceniza  marron oscuro  moreno claro / dorado  brillante
# 605     rubio ceniza  marron oscuro  moreno claro / dorado  brillante
# 606     rubio ceniza  marron oscuro  moreno claro / dorado  brillante
# 607     rubio ceniza  marron oscuro  moreno claro / dorado  brillante
# 608     rubio ceniza  marron oscuro  moreno / marron claro      suave
# 609     rubio ceniza  marron oscuro  moreno / marron claro      suave
# 610     rubio ceniza  marron oscuro  moreno / marron claro      suave
# 611     rubio ceniza  marron oscuro  moreno / marron claro      suave
# 612     rubio ceniza  marron oscuro  moreno / marron claro  brillante
# 613     rubio ceniza  marron oscuro  moreno / marron claro  brillante
# 614     rubio ceniza  marron oscuro  moreno / marron claro  brillante
# 615     rubio ceniza  marron oscuro  moreno / marron claro  brillante
# 616     rubio ceniza           azul              melocoton      suave
# 617     rubio ceniza           azul              melocoton      suave
# 618     rubio ceniza           azul              melocoton      suave
# 619     rubio ceniza           azul              melocoton      suave
# 620     rubio ceniza           azul              melocoton  brillante
# 621     rubio ceniza           azul              melocoton  brillante
# 622     rubio ceniza           azul              melocoton  brillante
# 623     rubio ceniza           azul              melocoton  brillante
# 624     rubio ceniza           azul        blanco / palido      suave
# 625     rubio ceniza           azul        blanco / palido      suave
# 626     rubio ceniza           azul        blanco / palido      suave
# 627     rubio ceniza           azul        blanco / palido      suave
# 628     rubio ceniza           azul        blanco / palido  brillante
# 629     rubio ceniza           azul        blanco / palido  brillante
# 630     rubio ceniza           azul        blanco / palido  brillante
# 631     rubio ceniza           azul        blanco / palido  brillante
# 632     rubio ceniza           azul                 rosada      suave
# 633     rubio ceniza           azul                 rosada      suave
# 634     rubio ceniza           azul                 rosada      suave
# 635     rubio ceniza           azul                 rosada      suave
# 636     rubio ceniza           azul                 rosada  brillante
# 637     rubio ceniza           azul                 rosada  brillante
# 638     rubio ceniza           azul                 rosada  brillante
# 639     rubio ceniza           azul                 rosada  brillante
# 640     rubio ceniza           azul                  negro      suave
# 641     rubio ceniza           azul                  negro      suave
# 642     rubio ceniza           azul                  negro      suave
# 643     rubio ceniza           azul                  negro      suave
# 644     rubio ceniza           azul                  negro  brillante
# 645     rubio ceniza           azul                  negro  brillante
# 646     rubio ceniza           azul                  negro  brillante
# 647     rubio ceniza           azul                  negro  brillante
# 648     rubio ceniza           azul            amarillento      suave
# 649     rubio ceniza           azul            amarillento      suave
# 650     rubio ceniza           azul            amarillento      suave
# 651     rubio ceniza           azul            amarillento      suave
# 652     rubio ceniza           azul            amarillento  brillante
# 653     rubio ceniza           azul            amarillento  brillante
# 654     rubio ceniza           azul            amarillento  brillante
# ...
# 4230     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4231     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4232      claro     cálido       claro       suave  PRIMAVERA
# 4233      claro     cálido       claro       suave  PRIMAVERA
# 4234      claro     cálido       claro       suave  PRIMAVERA
# 4235      claro     cálido       claro   brillante  PRIMAVERA
# 4236      claro     cálido       claro       suave  PRIMAVERA
# 4237      claro     cálido       claro   brillante  PRIMAVERA
# 4238      claro     cálido       claro   brillante  PRIMAVERA
# 4239      claro     cálido       claro   brillante  PRIMAVERA
# 4240     oscuro     cálido      oscuro       suave     VERANO
# 4241     oscuro     cálido      oscuro       suave     VERANO
# 4242     oscuro     cálido      oscuro       suave     VERANO
# 4243     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4244     oscuro     cálido      oscuro       suave     VERANO
# 4245     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4246     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4247     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4248     oscuro       frío      oscuro       suave      OTOÑO
# 4249     oscuro       frío      oscuro       suave      OTOÑO
# 4250     oscuro       frío      oscuro       suave      OTOÑO
# 4251     oscuro       frío      oscuro   brillante   INVIERNO
# 4252     oscuro       frío      oscuro       suave      OTOÑO
# 4253     oscuro       frío      oscuro   brillante   INVIERNO
# 4254     oscuro       frío      oscuro   brillante   INVIERNO
# 4255     oscuro       frío      oscuro   brillante   INVIERNO
# 4256     oscuro     cálido      oscuro       suave     VERANO
# 4257     oscuro     cálido      oscuro       suave     VERANO
# 4258     oscuro     cálido      oscuro       suave     VERANO
# 4259     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4260     oscuro     cálido      oscuro       suave     VERANO
# 4261     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4262     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4263     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4264     oscuro     cálido      oscuro       suave     VERANO
# 4265     oscuro     cálido      oscuro       suave     VERANO
# 4266     oscuro     cálido      oscuro       suave     VERANO
# 4267     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4268     oscuro     cálido      oscuro       suave     VERANO
# 4269     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4270     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4271     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4272      claro     cálido      oscuro       suave     VERANO
# 4273      claro     cálido      oscuro       suave     VERANO
# 4274      claro     cálido      oscuro       suave     VERANO
# 4275      claro     cálido      oscuro   brillante  PRIMAVERA
# 4276      claro     cálido      oscuro       suave     VERANO
# 4277      claro     cálido      oscuro   brillante  PRIMAVERA
# 4278      claro     cálido      oscuro   brillante  PRIMAVERA
# 4279      claro     cálido      oscuro   brillante  PRIMAVERA
# 4280     oscuro     cálido      oscuro       suave     VERANO
# 4281     oscuro     cálido      oscuro       suave     VERANO
# 4282     oscuro     cálido      oscuro       suave     VERANO
# 4283     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4284     oscuro     cálido      oscuro       suave     VERANO
# 4285     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4286     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4287     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4288      claro     cálido      oscuro       suave     VERANO
# 4289      claro     cálido      oscuro       suave     VERANO
# 4290      claro     cálido      oscuro       suave     VERANO
# 4291      claro     cálido      oscuro   brillante  PRIMAVERA
# 4292      claro     cálido      oscuro       suave     VERANO
# 4293      claro     cálido      oscuro   brillante  PRIMAVERA
# 4294      claro     cálido      oscuro   brillante  PRIMAVERA
# 4295      claro     cálido      oscuro   brillante  PRIMAVERA
# 4296     oscuro     cálido      oscuro       suave     VERANO
# 4297     oscuro     cálido      oscuro       suave     VERANO
# 4298     oscuro     cálido      oscuro       suave     VERANO
# 4299     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4300     oscuro     cálido      oscuro       suave     VERANO
# 4301     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4302     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4303     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4304     oscuro     cálido      oscuro       suave     VERANO
# 4305     oscuro     cálido      oscuro       suave     VERANO
# 4306     oscuro     cálido      oscuro       suave     VERANO
# 4307     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4308     oscuro     cálido      oscuro       suave     VERANO
# 4309     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4310     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4311     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4312     oscuro       frío      oscuro       suave      OTOÑO
# 4313     oscuro       frío      oscuro       suave      OTOÑO
# 4314     oscuro       frío      oscuro       suave      OTOÑO
# 4315     oscuro       frío      oscuro   brillante   INVIERNO
# 4316     oscuro       frío      oscuro       suave      OTOÑO
# 4317     oscuro       frío      oscuro   brillante   INVIERNO
# 4318     oscuro       frío      oscuro   brillante   INVIERNO
# 4319     oscuro       frío      oscuro   brillante   INVIERNO
# 4320     oscuro       frío      oscuro       suave      OTOÑO
# 4321     oscuro       frío      oscuro       suave      OTOÑO
# 4322     oscuro       frío      oscuro       suave      OTOÑO
# 4323     oscuro       frío      oscuro   brillante   INVIERNO
# 4324     oscuro       frío      oscuro       suave      OTOÑO
# 4325     oscuro       frío      oscuro   brillante   INVIERNO
# 4326     oscuro       frío      oscuro   brillante   INVIERNO
# 4327     oscuro       frío      oscuro   brillante   INVIERNO
# 4328      claro       frío      oscuro       suave      OTOÑO
# 4329      claro       frío      oscuro       suave      OTOÑO
# 4330      claro       frío      oscuro       suave      OTOÑO
# 4331      claro       frío      oscuro   brillante   INVIERNO
# 4332      claro       frío      oscuro       suave      OTOÑO
# 4333      claro       frío      oscuro   brillante   INVIERNO
# 4334      claro       frío      oscuro   brillante   INVIERNO
# 4335      claro       frío      oscuro   brillante   INVIERNO
# 4336     oscuro     cálido      oscuro       suave     VERANO
# 4337     oscuro     cálido      oscuro       suave     VERANO
# 4338     oscuro     cálido      oscuro       suave     VERANO
# 4339     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4340     oscuro     cálido      oscuro       suave     VERANO
# 4341     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4342     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4343     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4344      claro     cálido      oscuro       suave     VERANO
# 4345      claro     cálido      oscuro       suave     VERANO
# 4346      claro     cálido      oscuro       suave     VERANO
# 4347      claro     cálido      oscuro   brillante  PRIMAVERA
# 4348      claro     cálido      oscuro       suave     VERANO
# 4349      claro     cálido      oscuro   brillante  PRIMAVERA
# 4350      claro     cálido      oscuro   brillante  PRIMAVERA
# 4351      claro     cálido      oscuro   brillante  PRIMAVERA
# 4352     oscuro     cálido      oscuro       suave     VERANO
# 4353     oscuro     cálido      oscuro       suave     VERANO
# 4354     oscuro     cálido      oscuro       suave     VERANO
# 4355     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4356     oscuro     cálido      oscuro       suave     VERANO
# 4357     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4358     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4359     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4360     oscuro       frío      oscuro       suave      OTOÑO
# 4361     oscuro       frío      oscuro       suave      OTOÑO
# 4362     oscuro       frío      oscuro       suave      OTOÑO
# 4363     oscuro       frío      oscuro   brillante   INVIERNO
# 4364     oscuro       frío      oscuro       suave      OTOÑO
# 4365     oscuro       frío      oscuro   brillante   INVIERNO
# 4366     oscuro       frío      oscuro   brillante   INVIERNO
# 4367     oscuro       frío      oscuro   brillante   INVIERNO
# 4368     oscuro     cálido      oscuro       suave     VERANO
# 4369     oscuro     cálido      oscuro       suave     VERANO
# 4370     oscuro     cálido      oscuro       suave     VERANO
# 4371     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4372     oscuro     cálido      oscuro       suave     VERANO
# 4373     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4374     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4375     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4376     oscuro     cálido      oscuro       suave     VERANO
# 4377     oscuro     cálido      oscuro       suave     VERANO
# 4378     oscuro     cálido      oscuro       suave     VERANO
# 4379     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4380     oscuro     cálido      oscuro       suave     VERANO
# 4381     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4382     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4383     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4384      claro     cálido       claro       suave  PRIMAVERA
# 4385      claro     cálido       claro       suave  PRIMAVERA
# 4386      claro     cálido       claro       suave  PRIMAVERA
# 4387      claro     cálido       claro   brillante  PRIMAVERA
# 4388      claro     cálido       claro       suave  PRIMAVERA
# 4389      claro     cálido       claro   brillante  PRIMAVERA
# 4390      claro     cálido       claro   brillante  PRIMAVERA
# 4391      claro     cálido       claro   brillante  PRIMAVERA
# 4392     oscuro     cálido      oscuro       suave     VERANO
# 4393     oscuro     cálido      oscuro       suave     VERANO
# 4394     oscuro     cálido      oscuro       suave     VERANO
# 4395     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4396     oscuro     cálido      oscuro       suave     VERANO
# 4397     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4398     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4399     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4400      claro     cálido       claro       suave  PRIMAVERA
# 4401      claro     cálido       claro       suave  PRIMAVERA
# 4402      claro     cálido       claro       suave  PRIMAVERA
# 4403      claro     cálido       claro   brillante  PRIMAVERA
# 4404      claro     cálido       claro       suave  PRIMAVERA
# 4405      claro     cálido       claro   brillante  PRIMAVERA
# 4406      claro     cálido       claro   brillante  PRIMAVERA
# 4407      claro     cálido       claro   brillante  PRIMAVERA
# 4408     oscuro     cálido      oscuro       suave     VERANO
# 4409     oscuro     cálido      oscuro       suave     VERANO
# 4410     oscuro     cálido      oscuro       suave     VERANO
# 4411     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4412     oscuro     cálido      oscuro       suave     VERANO
# 4413     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4414     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4415     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4416     oscuro     cálido      oscuro       suave     VERANO
# 4417     oscuro     cálido      oscuro       suave     VERANO
# 4418     oscuro     cálido      oscuro       suave     VERANO
# 4419     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4420     oscuro     cálido      oscuro       suave     VERANO
# 4421     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4422     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4423     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4424     oscuro     cálido      oscuro       suave     VERANO
# 4425     oscuro     cálido      oscuro       suave     VERANO
# 4426     oscuro     cálido      oscuro       suave     VERANO
# 4427     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4428     oscuro     cálido      oscuro       suave     VERANO
# 4429     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4430     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4431     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4432     oscuro     cálido      oscuro       suave     VERANO
# 4433     oscuro     cálido      oscuro       suave     VERANO
# 4434     oscuro     cálido      oscuro       suave     VERANO
# 4435     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4436     oscuro     cálido      oscuro       suave     VERANO
# 4437     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4438     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4439     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4440      claro     cálido       claro       suave  PRIMAVERA
# 4441      claro     cálido       claro       suave  PRIMAVERA
# 4442      claro     cálido       claro       suave  PRIMAVERA
# 4443      claro     cálido       claro   brillante  PRIMAVERA
# 4444      claro     cálido       claro       suave  PRIMAVERA
# 4445      claro     cálido       claro   brillante  PRIMAVERA
# 4446      claro     cálido       claro   brillante  PRIMAVERA
# 4447      claro     cálido       claro   brillante  PRIMAVERA
# 4448     oscuro     cálido      oscuro       suave     VERANO
# 4449     oscuro     cálido      oscuro       suave     VERANO
# 4450     oscuro     cálido      oscuro       suave     VERANO
# 4451     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4452     oscuro     cálido      oscuro       suave     VERANO
# 4453     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4454     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4455     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4456      claro     cálido       claro       suave  PRIMAVERA
# 4457      claro     cálido       claro       suave  PRIMAVERA
# 4458      claro     cálido       claro       suave  PRIMAVERA
# 4459      claro     cálido       claro   brillante  PRIMAVERA
# 4460      claro     cálido       claro       suave  PRIMAVERA
# 4461      claro     cálido       claro   brillante  PRIMAVERA
# 4462      claro     cálido       claro   brillante  PRIMAVERA
# 4463      claro     cálido       claro   brillante  PRIMAVERA
# 4464     oscuro     cálido      oscuro       suave     VERANO
# 4465     oscuro     cálido      oscuro       suave     VERANO
# 4466     oscuro     cálido      oscuro       suave     VERANO
# 4467     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4468     oscuro     cálido      oscuro       suave     VERANO
# 4469     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4470     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4471     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4472     oscuro     cálido      oscuro       suave     VERANO
# 4473     oscuro     cálido      oscuro       suave     VERANO
# 4474     oscuro     cálido      oscuro       suave     VERANO
# 4475     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4476     oscuro     cálido      oscuro       suave     VERANO
# 4477     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4478     oscuro     cálido      oscuro   brillante  PRIMAVERA
# 4479     oscuro     cálido      oscuro   brillante  PRIMAVERA

# %% [markdown]
# https://www.hogarmania.com/belleza/moda/ropa/colores-iluminan-rostro-5861.html \
# LINK DE LOS TIPOS DE PALETAS

# %%
combinaciones2 = combinaciones[['CABELLO', 'CROMA_CAB', 'OJOS', 'CROMA_OJOS', 'PIEL', 'CROMA_PIEL']]

# %%
combinaciones2.head()
# Out:
#    CABELLO  CROMA_CAB  OJOS CROMA_OJOS       PIEL CROMA_PIEL
# ID
# 0    rubio      suave  gris      suave  melocoton      suave
# 1    rubio      suave  gris      suave  melocoton  brillante
# 2    rubio      suave  gris  brillante  melocoton      suave
# 3    rubio      suave  gris  brillante  melocoton  brillante
# 4    rubio  brillante  gris      suave  melocoton      suave

# %%
combinaciones[(combinaciones.CABELLO == 'rubio') & (combinaciones.OJOS == 'gris') & (combinaciones.PIEL ==\
             'melocoton') &  (combinaciones.CROMA_CAB == 'suave') & (combinaciones.CROMA_OJOS == 'brillante')\
             & (combinaciones.CROMA_PIEL == 'suave')]['PALETAS']
# Out:
# ID
# 2    OTOÑO
# Name: PALETAS, dtype: category
# Categories (4, object): ['INVIERNO', 'OTOÑO', 'PRIMAVERA', 'VERANO']

# %% [markdown]
# **IMPORTACIONES**

# %%
import pandas as pd
import itertools as it
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# **CREACIÓN DE TABLAS DE COLORES POR FACCIÓN**

# %%
#COLOR DE LAS FACCIONES
color_cab = ['rubio', 'rubio ceniza', 'rubio platino', 'castano', 'castano claro', 'castano oscuro',\
            'chocolate', 'negro', 'pelirrojo', 'caoba']
color_ojos = ['miel', 'verde', 'ambar', 'almendra', 'azul', 'marron oscuro', 'negro', 'gris']
color_piel = ['moreno / marron claro', 'moreno claro / dorado', 'amarillento', \
              'negro', 'rosada', 'blanco / palido', 'melocoton']

# %%
data1 = {'ID' : [e for e in range(len(color_cab))], 'COLORES' : color_cab,  'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'cabello'}
data2 = {'ID' : [e for e in range(len(color_ojos))], 'COLORES' : color_ojos,  'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'ojos'}
data3 = {'ID' : [e for e in range(len(color_piel))], 'COLORES' : color_piel, 'TEMP' : 'temperatura', \
        'VALOR' : 'valores', 'TIPO' : 'piel'}

# %%
#TABLAS
cabello = pd.DataFrame(data1)
ojos = pd.DataFrame(data2)
piel = pd.DataFrame(data3)

# %% [markdown]
# Debemos diferenciar entre la temperatura, el valor y el croma de cada color de las facciones, siendo los siguientes:
#
#   1. **TEMPERATURA**:
#
# *frios* = ['castaño oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / pálido',
#             'marrón oscuro', 'negro', 'azul', 'gris']
#
# *calidos* = ['rubio', 'castaño', 'castaño claro', 'pelirrojo', 'moreno / marrón claro', 'moreno claro / dorado',
#               'amarillento','negro', 'melocotón', 'miel', 'verde', 'ámbar', 'almendra', 'caoba']
#
#   2. **VALOR**:
#
# *claro* = ['rubio', 'castaño', 'castaño claro', 'pelirrojo',
#             'rubio platino', 'rubio ceniza', 'rosada', 'blanco /  pálido', 'amarillento', 'melocotón',
#             'miel', 'verde', 'ámbar', 'azul', 'gris', 'almendra']
#
# *oscuro* =['castaño oscuro', 'chocolate', 'negro', 'marrón oscuro', 'negro', 'moreno / marrón claro', 'moreno claro
#          dorado', 'negro', 'almendra', 'caoba']
#
#    3. **CROMA**:
#
# *brillante* - pieles, ojos y cabellos monocromáticos
#
# *suave* - pieles, ojos y cabellos con policromáticos (mechas o reflejos, ojos con más de un color, etc.)

# %%
claro = ['rubio', 'castano', 'castano claro', 'pelirrojo', \
            'rubio platino', 'rubio ceniza', 'rosada', 'blanco /  palido', 'amarillento', 'melocoton', \
            'miel', 'verde', 'ambar', 'azul', 'gris']

oscuro = ['castaño oscuro', 'chocolate', 'negro', 'marrón oscuro', 'negro', 'moreno / marrón claro', \
         'moreno claro / dorado', 'negro', 'almendra', 'caoba']

# %%
frios = ['castano oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido',\
            'marron oscuro', 'negro', 'azul', 'gris']

calidos = ['rubio', 'castaño', 'castaño claro', 'pelirrojo', 'moreno / marrón claro', 'moreno claro / dorado',\
          'amarillento','negro', 'melocotón', 'miel', 'verde', 'ámbar', 'almendra', 'caoba']

# %%
#COLUMNA'TEMPERATURA' - CABELLO
frios = ['castano oscuro', 'chocolate', 'negro', 'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido',\
            'marron oscuro', 'negro', 'azul', 'gris']
temp1 = []
for e in cabello.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

cabello.TEMP = temp1

# %%
#COLUMNA'TEMPERATURA' - OJOS
temp1 = []
for e in ojos.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

ojos.TEMP = temp1

# %%
#COLUMNA'TEMPERATURA' - PIEL
temp1 = []
for e in piel.COLORES:
    if e in frios:
        temp1.append('frio')
    else:
        temp1.append('calido')

piel.TEMP = temp1

# %%
#COLUMNA 'VALOR' - CABELLO
claro = ['rubio', 'castano', 'castano claro', 'pelirrojo', \
            'rubio platino', 'rubio ceniza', 'rosada', 'blanco / palido', 'amarillento', 'melocoton', \
            'miel', 'verde', 'ambar', 'azul', 'gris']
temp2 = []
for e in cabello.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

cabello.VALOR = temp2

# %%
cabello
# Out:
#    ID         COLORES    TEMP   VALOR     TIPO
# 0   0           rubio  calido   claro  cabello
# 1   1    rubio ceniza    frio   claro  cabello
# 2   2   rubio platino    frio   claro  cabello
# 3   3         castano  calido   claro  cabello
# 4   4   castano claro  calido   claro  cabello
# 5   5  castano oscuro    frio  oscuro  cabello
# 6   6       chocolate    frio  oscuro  cabello
# 7   7           negro    frio  oscuro  cabello
# 8   8       pelirrojo  calido   claro  cabello
# 9   9           caoba  calido  oscuro  cabello

# %%
#COLUMNA 'VALOR' - OJOS
temp2 = []
for e in ojos.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

ojos.VALOR = temp2

# %%
ojos
# Out:
#    ID        COLORES    TEMP   VALOR  TIPO
# 0   0           miel  calido   claro  ojos
# 1   1          verde  calido   claro  ojos
# 2   2          ambar  calido   claro  ojos
# 3   3       almendra  calido  oscuro  ojos
# 4   4           azul    frio   claro  ojos
# 5   5  marron oscuro    frio  oscuro  ojos
# 6   6          negro    frio  oscuro  ojos
# 7   7           gris    frio   claro  ojos

# %%
#COLUMNA 'VALOR' - PIEL
temp2 = []
for e in piel.COLORES:
    if e in claro:
        temp2.append('claro')
    else:
        temp2.append('oscuro')

piel.VALOR = temp2

# %%
piel
# Out:
#    ID                COLORES    TEMP   VALOR  TIPO
# 0   0  moreno / marron claro  calido  oscuro  piel
# 1   1  moreno claro / dorado  calido  oscuro  piel
# 2   2            amarillento  calido   claro  piel
# 3   3                  negro    frio  oscuro  piel
# 4   4                 rosada    frio   claro  piel
# 5   5        blanco / palido    frio   claro  piel
# 6   6              melocoton  calido   claro  piel

# %%
#TABLA 'CROMA'
data4 = {'ID' : [1, 2], 'CROMA_CAB' : ['brillante', 'suave'], 'CROMA_OJOS' : ['brillante', 'suave'],\
        'CROMA_PIEL' : ['brillante', 'suave']}
croma = pd.DataFrame(data4)

# %% [markdown]
# Vamos a pasar las tablas a SQL ya que se nos facilita la combinación entre ellas

# %%
str_conn='mysql+pymysql://root:01051997Rm@localhost:3306/PROYECTO_FINAL'

cursor=create_engine(str_conn)

# %%
cabello.to_sql(name='cabello', con=cursor, if_exists='replace', index=False)
ojos.to_sql(name='ojos', con=cursor, if_exists='replace', index=False)
piel.to_sql(name='piel', con=cursor, if_exists='replace', index=False)
croma.to_sql(name='croma', con=cursor, if_exists='replace', index=False)
# Out:
# 2

# %% [markdown]
# Traemos la tabla 'combinaciones' de MYSQL, ya que contiene todas las combinaciones posibles de colores de pelo, ojos y piel + los CROMAS

# %%
combinaciones = pd.read_csv('../PROYECTO-FINAL-IRONHACK/DATA/combinaciones_def.csv', sep = ';')

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL
# 0   rubio  gris  melocoton      suave      suave      suave
# 1   rubio  gris  melocoton      suave      suave  brillante
# 2   rubio  gris  melocoton      suave  brillante      suave
# 3   rubio  gris  melocoton      suave  brillante  brillante
# 4   rubio  gris  melocoton  brillante      suave      suave

# %% [markdown]
# Vamos a añadir 6 columnas más: TEMP_CABELLO, TEMP_OJOS, TEMP_PIEL, VALOR_CABELLO, VALOR_OJOS Y VALOR_PIEL.
# De esta forma, luego será más fácil identificar la paleta que corresponda a cada uno de los casos.

# %%
#Definimos los casos de temperatura para cada fila del dataframe 'combinaciones'

temperaturas_cab = []
temperaturas_ojos = []
temperaturas_piel = []

for e in combinaciones.CABELLO:
    if e in calidos:
        temperaturas_cab.append('calido')
    else:
        temperaturas_cab.append('frio')

for e in combinaciones.OJOS:
    if e in calidos:
        temperaturas_ojos.append('calido')
    else:
        temperaturas_ojos.append('frio')
        
for e in combinaciones.PIEL:
    if e in calidos:
        temperaturas_piel.append('calido')
    else:
        temperaturas_piel.append('frio')

# %%
#Definimos los casos de valores para cada fila del dataframe 'combinaciones'

valores_cab = []
valores_ojos = []
valores_piel = []

for e in combinaciones.CABELLO:
    if e in claro:
        valores_cab.append('claro')
    else:
        valores_cab.append('oscuro')
        
for e in combinaciones.OJOS:
    if e in claro:
        valores_ojos.append('claro')
    else:
        valores_ojos.append('oscuro')
        
for e in combinaciones.PIEL:
    if e in claro:
        valores_piel.append('claro')
    else:
        valores_piel.append('oscuro')

# %%
#Creamos las columnas e igualamos sus valores a las listas que hemos creado anteriormente.
combinaciones['TEMP_OJOS'] = temperaturas_ojos
combinaciones['TEMP_PIEL'] = temperaturas_piel
combinaciones['TEMP_CAB'] = temperaturas_cab
combinaciones['VALOR_CAB'] = valores_cab
combinaciones['VALOR_OJOS'] = valores_ojos
combinaciones['VALOR_PIEL'] = valores_piel

# %%
len(combinaciones)
# Out:
# 4480

# %% [markdown]
# Ahora, debemos diferenciar las diferentes paletas de colores que tendremos. Estas son:
#
#    1. **PRIMAVERA** - CÁLIDA, CLARA, BRILLANTE
#
#    2. **OTOÑO** - FRÍO, CLARO, SUAVE
#
#    3. **VERANO** - CÁLIDO, OSCURO, BRILLANTE
#
#    4. **INVIERNO** - FRÍO, OSCURO, BRILLANTE

# %%
#Determinamos si el total de cada fila es cálido o frío para poder asignar su paleta
temp = []
for i in combinaciones.index:
    if combinaciones['TEMP_CAB'][i] == 'calido' and ((combinaciones['TEMP_OJOS'][i] == 'calido') or \
                                                     (combinaciones['TEMP_PIEL'][i] == 'calido')):\
        temp.append('calido')
    elif str(combinaciones['TEMP_CAB'][i]) == 'frio' and ((combinaciones['TEMP_OJOS'][i]  == 'frio') or\
                                                     (combinaciones['TEMP_PIEL'][i]  == 'frio')):\
       
        temp.append('frio')
    elif combinaciones['TEMP_OJOS'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'calido' or \
                                                       combinaciones['TEMP_PIEL'][i] == 'calido'):\
        
        temp.append('calido')
    elif combinaciones['TEMP_OJOS'][i] == 'frio' and (combinaciones['TEMP_CAB'][i] == 'frio' or\
                                                      combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')
    elif combinaciones['TEMP_PIEL'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'calido' or\
                                                        combinaciones['TEMP_OJOS'][i] == 'calido'):\
        
        temp.append('calido')
    elif combinaciones['TEMP_PIEL'][i] == 'frio' and (combinaciones['TEMP_OJOS'][i] == 'frio' or\
                                                      combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')

    elif combinaciones['TEMP_OJOS'][i] == 'calido' and (combinaciones['TEMP_CAB'][i] == 'frio' and\
                                                        combinaciones['TEMP_PIEL'][i] == 'frio'):\
        
        temp.append('frio')
    else:
        temp.append('no')

combinaciones['TEMP_TOTAL'] = temp

# %%
#Determinamos si el total de cada fila es claro u oscuro para poder asignar su paleta
val = []
for i in combinaciones.index:
    if combinaciones['VALOR_CAB'][i] == 'claro' and ((combinaciones['VALOR_OJOS'][i] == 'claro') or \
                                                     (combinaciones['VALOR_PIEL'][i] == 'claro')):\
        val.append('claro')
    elif str(combinaciones['VALOR_CAB'][i]) == 'oscuro' and ((combinaciones['VALOR_OJOS'][i]  == 'oscuro') or\
                                                     (combinaciones['VALOR_PIEL'][i]  == 'oscuro')):\
       
        val.append('oscuro')
    elif combinaciones['VALOR_OJOS'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'claro' or \
                                                       combinaciones['VALOR_PIEL'][i] == 'claro'):\
        
        val.append('claro')
    elif combinaciones['VALOR_OJOS'][i] == 'oscuro' and (combinaciones['VALOR_CAB'][i] == 'oscuro' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')
    elif combinaciones['VALOR_PIEL'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'claro' or\
                                                        combinaciones['VALOR_OJOS'][i] == 'claro'):\
        
        val.append('claro')
    elif combinaciones['VALOR_PIEL'][i] == 'oscuro' and (combinaciones['VALOR_OJOS'][i] == 'oscuro' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')

    elif combinaciones['VALOR_OJOS'][i] == 'claro' and (combinaciones['VALOR_CAB'][i] == 'oscuro' and\
                                                        combinaciones['VALOR_PIEL'][i] == 'oscuro'):\
        
        val.append('oscuro')
    else:
        val.append('no')

combinaciones['VALOR_TOTAL'] = val

# %%
#Determinamos si el total de cada fila es suave o brillante para poder asignar su paleta
cr = []
for i in combinaciones.index:
    if combinaciones['CROMA_CAB'][i] == 'brillante' and ((combinaciones['CROMA_OJOS'][i] == 'brillante') or \
                                                     (combinaciones['CROMA_PIEL'][i] == 'brillante')):\
        cr.append('brillante')
    elif str(combinaciones['CROMA_CAB'][i]) == 'suave' and ((combinaciones['CROMA_OJOS'][i]  == 'suave') or\
                                                     (combinaciones['CROMA_PIEL'][i]  == 'suave')):\
       
        cr.append('suave')
    elif combinaciones['CROMA_OJOS'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'brillante' or \
                                                       combinaciones['CROMA_PIEL'][i] == 'brillante'):\
        
        cr.append('brillante')
    elif combinaciones['CROMA_OJOS'][i] == 'suave' and (combinaciones['CROMA_CAB'][i] == 'suave' or\
                                                      combinaciones['CROMA_PIEL'][i] == 'suave'):\
        
        cr.append('suave')
    elif combinaciones['CROMA_PIEL'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'brillante' or\
                                                        combinaciones['CROMA_OJOS'][i] == 'brillante'):\
        
        cr.append('brillante')
    elif combinaciones['CROMA_PIEL'][i] == 'suave' and (combinaciones['CROMA_OJOS'][i] == 'suave' or\
                                                      combinaciones['VALOR_PIEL'][i] == 'suave'):\
        
        cr.append('suave')

    elif combinaciones['CROMA_OJOS'][i] == 'brillante' and (combinaciones['CROMA_CAB'][i] == 'suave' and\
                                                        combinaciones['CROMA_PIEL'][i] == 'suave'):\
        
        cr.append('suave')
    else:
        cr.append('no')


combinaciones['CROMA_TOTAL'] = cr

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL TEMP_OJOS  \
# 0   rubio  gris  melocoton      suave      suave      suave      frio
# 1   rubio  gris  melocoton      suave      suave  brillante      frio
# 2   rubio  gris  melocoton      suave  brillante      suave      frio
# 3   rubio  gris  melocoton      suave  brillante  brillante      frio
# 4   rubio  gris  melocoton  brillante      suave      suave      frio
#
#   TEMP_PIEL TEMP_CAB VALOR_CAB VALOR_OJOS VALOR_PIEL TEMP_TOTAL VALOR_TOTAL  \
# 0      frio   calido     claro      claro      claro       frio       claro
# 1      frio   calido     claro      claro      claro       frio       claro
# 2      frio   calido     claro      claro      claro       frio       claro
# 3      frio   calido     claro      claro      claro       frio       claro
# 4      frio   calido     claro      claro      claro       frio       claro
#
#   CROMA_TOTAL
# 0       suave
# 1       suave
# 2       suave
# 3   brillante
# 4       suave

# %% [markdown]
# Ahora, debemos asignar las paletas de colores. Para ello, crearemos la columna 'PALETA'

# %%
#Vamos a crear listas que contengan la temperatura, valor y croma de cada paleta.
prim = ['calido', 'claro', 'brillante']
oto = ['frio', 'claro', 'suave']
ver = ['calido', 'oscuro', 'brillante']
inv = ['frio', 'oscuro', 'brillante']

# %%
#Ahora, en función de los valores por cada columna, debemos asignar la paleta PRIMAVERA, OTOÑO, INVIERNO o VERANO.
paletas = []

for i in combinaciones.index:

    if (combinaciones['TEMP_TOTAL'][i] in prim) and (combinaciones['VALOR_TOTAL'][i] in prim\
                                                     or combinaciones['CROMA_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')

    elif (combinaciones['TEMP_TOTAL'][i] in oto) and (combinaciones['VALOR_TOTAL'][i] in oto\
                                                      or combinaciones['CROMA_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')
        
    elif (combinaciones['TEMP_TOTAL'][i] in ver) and (combinaciones['VALOR_TOTAL'][i] in ver\
                                                     or combinaciones['CROMA_TOTAL'][i] in ver):\
        paletas.append('VERANO')

    elif (combinaciones['TEMP_TOTAL'][i] in inv) and (combinaciones['VALOR_TOTAL'][i] in inv\
                                                     or combinaciones['CROMA_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
        
    elif (combinaciones['VALOR_TOTAL'][i] in oto) and (combinaciones['TEMP_TOTAL'][i] in oto\
                                                     or combinaciones['CROMA_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')

    elif (combinaciones['VALOR_TOTAL'][i] in ver) and (combinaciones['TEMP_TOTAL'][i] in ver\
                                                     or combinaciones['CROMA_TOTAL'][i] in ver):\
        paletas.append('VERANO')
        
    elif (combinaciones['VALOR_TOTAL'][i] in prim) and (combinaciones['TEMP_TOTAL'][i] in prim\
                                                     or combinaciones['CROMA_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')
        
    elif (combinaciones['VALOR_TOTAL'][i] in inv) and (combinaciones['TEMP_TOTAL'][i] in inv\
                                                     or combinaciones['CROMA_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in prim) and (combinaciones['TEMP_TOTAL'][i] in prim\
                                                     or combinaciones['VALOR_TOTAL'][i] in prim):\
        paletas.append('PRIMAVERA')
        
    elif (combinaciones['CROMA_TOTAL'][i] in oto) and (combinaciones['VALOR_TOTAL'][i] in oto\
                                                     or combinaciones['TEMP_TOTAL'][i] in oto):\
        paletas.append('OTOÑO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in ver) and (combinaciones['VALOR_TOTAL'][i] in ver\
                                                     or combinaciones['TEMP_TOTAL'][i] in ver):\
        paletas.append('VERANO')
        
    elif (combinaciones['CROMA_TOTAL'][i] in inv) and (combinaciones['TEMP_TOTAL'][i] in inv\
                                                     or combinaciones['VALOR_TOTAL'][i] in inv):\
        paletas.append('INVIERNO')
    else:
        paletas.append('no')

# %%
combinaciones['PALETAS'] = paletas

# %%
combinaciones.head()
# Out:
#   CABELLO  OJOS       PIEL  CROMA_CAB CROMA_OJOS CROMA_PIEL TEMP_OJOS  \
# 0   rubio  gris  melocoton      suave      suave      suave      frio
# 1   rubio  gris  melocoton      suave      suave  brillante      frio
# 2   rubio  gris  melocoton      suave  brillante      suave      frio
# 3   rubio  gris  melocoton      suave  brillante  brillante      frio
# 4   rubio  gris  melocoton  brillante      suave      suave      frio
#
#   TEMP_PIEL TEMP_CAB VALOR_CAB VALOR_OJOS VALOR_PIEL TEMP_TOTAL VALOR_TOTAL  \
# 0      frio   calido     claro      claro      claro       frio       claro
# 1      frio   calido     claro      claro      claro       frio       claro
# 2      frio   calido     claro      claro      claro       frio       claro
# 3      frio   calido     claro      claro      claro       frio       claro
# 4      frio   calido     claro      claro      claro       frio       claro
#
#   CROMA_TOTAL PALETAS
# 0       suave   OTOÑO
# 1       suave   OTOÑO
# 2       suave   OTOÑO
# 3   brillante   OTOÑO
# 4       suave   OTOÑO

# %%
#Volvemos a poner las 'ñ' a las palabras ya que en SQL hemos tenido que borrarlas porque el programa no lo cogía
def quitar_n(columna):
    if columna == 'castano':
        return 'castaño'
    elif columna == 'castano claro':
        return 'castaño claro'
    elif columna == 'castano oscuro':
        return 'castaño oscuro'
    else:
        return columna

# %%
combinaciones.CABELLO = combinaciones.CABELLO.apply(quitar_n)

# %%
columna = [e for e in range(len(combinaciones))]

# %%
#Añadimos un ID como indice 
combinaciones.set_index('ID', drop = True, inplace = True)

# %%
combinaciones.head(200)
# Out:
#     CABELLO           OJOS                   PIEL  CROMA_CAB CROMA_OJOS  \
# ID
# 0     rubio           gris              melocoton      suave      suave
# 1     rubio           gris              melocoton      suave      suave
# 2     rubio           gris              melocoton      suave  brillante
# 3     rubio           gris              melocoton      suave  brillante
# 4     rubio           gris              melocoton  brillante      suave
# 5     rubio           gris              melocoton  brillante      suave
# 6     rubio           gris              melocoton  brillante  brillante
# 7     rubio           gris              melocoton  brillante  brillante
# 8     rubio           gris        blanco / palido      suave      suave
# 9     rubio           gris        blanco / palido      suave      suave
# 10    rubio           gris        blanco / palido      suave  brillante
# 11    rubio           gris        blanco / palido      suave  brillante
# 12    rubio           gris        blanco / palido  brillante      suave
# 13    rubio           gris        blanco / palido  brillante      suave
# 14    rubio           gris        blanco / palido  brillante  brillante
# 15    rubio           gris        blanco / palido  brillante  brillante
# 16    rubio           gris                 rosada      suave      suave
# 17    rubio           gris                 rosada      suave      suave
# 18    rubio           gris                 rosada      suave  brillante
# 19    rubio           gris                 rosada      suave  brillante
# 20    rubio           gris                 rosada  brillante      suave
# 21    rubio           gris                 rosada  brillante      suave
# 22    rubio           gris                 rosada  brillante  brillante
# 23    rubio           gris                 rosada  brillante  brillante
# 24    rubio           gris                  negro      suave      suave
# 25    rubio           gris                  negro      suave      suave
# 26    rubio           gris                  negro      suave  brillante
# 27    rubio           gris                  negro      suave  brillante
# 28    rubio           gris                  negro  brillante      suave
# 29    rubio           gris                  negro  brillante      suave
# 30    rubio           gris                  negro  brillante  brillante
# 31    rubio           gris                  negro  brillante  brillante
# 32    rubio           gris            amarillento      suave      suave
# 33    rubio           gris            amarillento      suave      suave
# 34    rubio           gris            amarillento      suave  brillante
# 35    rubio           gris            amarillento      suave  brillante
# 36    rubio           gris            amarillento  brillante      suave
# 37    rubio           gris            amarillento  brillante      suave
# 38    rubio           gris            amarillento  brillante  brillante
# 39    rubio           gris            amarillento  brillante  brillante
# 40    rubio           gris  moreno claro / dorado      suave      suave
# 41    rubio           gris  moreno claro / dorado      suave      suave
# 42    rubio           gris  moreno claro / dorado      suave  brillante
# 43    rubio           gris  moreno claro / dorado      suave  brillante
# 44    rubio           gris  moreno claro / dorado  brillante      suave
# 45    rubio           gris  moreno claro / dorado  brillante      suave
# 46    rubio           gris  moreno claro / dorado  brillante  brillante
# 47    rubio           gris  moreno claro / dorado  brillante  brillante
# 48    rubio           gris  moreno / marron claro      suave      suave
# 49    rubio           gris  moreno / marron claro      suave      suave
# 50    rubio           gris  moreno / marron claro      suave  brillante
# 51    rubio           gris  moreno / marron claro      suave  brillante
# 52    rubio           gris  moreno / marron claro  brillante      suave
# 53    rubio           gris  moreno / marron claro  brillante      suave
# 54    rubio           gris  moreno / marron claro  brillante  brillante
# 55    rubio           gris  moreno / marron claro  brillante  brillante
# 56    rubio          negro              melocoton      suave      suave
# 57    rubio          negro              melocoton      suave      suave
# 58    rubio          negro              melocoton      suave  brillante
# 59    rubio          negro              melocoton      suave  brillante
# 60    rubio          negro              melocoton  brillante      suave
# 61    rubio          negro              melocoton  brillante      suave
# 62    rubio          negro              melocoton  brillante  brillante
# 63    rubio          negro              melocoton  brillante  brillante
# 64    rubio          negro        blanco / palido      suave      suave
# 65    rubio          negro        blanco / palido      suave      suave
# 66    rubio          negro        blanco / palido      suave  brillante
# 67    rubio          negro        blanco / palido      suave  brillante
# 68    rubio          negro        blanco / palido  brillante      suave
# 69    rubio          negro        blanco / palido  brillante      suave
# 70    rubio          negro        blanco / palido  brillante  brillante
# 71    rubio          negro        blanco / palido  brillante  brillante
# 72    rubio          negro                 rosada      suave      suave
# 73    rubio          negro                 rosada      suave      suave
# 74    rubio          negro                 rosada      suave  brillante
# 75    rubio          negro                 rosada      suave  brillante
# 76    rubio          negro                 rosada  brillante      suave
# 77    rubio          negro                 rosada  brillante      suave
# 78    rubio          negro                 rosada  brillante  brillante
# 79    rubio          negro                 rosada  brillante  brillante
# 80    rubio          negro                  negro      suave      suave
# 81    rubio          negro                  negro      suave      suave
# 82    rubio          negro                  negro      suave  brillante
# 83    rubio          negro                  negro      suave  brillante
# 84    rubio          negro                  negro  brillante      suave
# 85    rubio          negro                  negro  brillante      suave
# 86    rubio          negro                  negro  brillante  brillante
# 87    rubio          negro                  negro  brillante  brillante
# 88    rubio          negro            amarillento      suave      suave
# 89    rubio          negro            amarillento      suave      suave
# 90    rubio          negro            amarillento      suave  brillante
# 91    rubio          negro            amarillento      suave  brillante
# 92    rubio          negro            amarillento  brillante      suave
# 93    rubio          negro            amarillento  brillante      suave
# 94    rubio          negro            amarillento  brillante  brillante
# 95    rubio          negro            amarillento  brillante  brillante
# 96    rubio          negro  moreno claro / dorado      suave      suave
# 97    rubio          negro  moreno claro / dorado      suave      suave
# 98    rubio          negro  moreno claro / dorado      suave  brillante
# 99    rubio          negro  moreno claro / dorado      suave  brillante
# 100   rubio          negro  moreno claro / dorado  brillante      suave
# 101   rubio          negro  moreno claro / dorado  brillante      suave
# 102   rubio          negro  moreno claro / dorado  brillante  brillante
# 103   rubio          negro  moreno claro / dorado  brillante  brillante
# 104   rubio          negro  moreno / marron claro      suave      suave
# 105   rubio          negro  moreno / marron claro      suave      suave
# 106   rubio          negro  moreno / marron claro      suave  brillante
# 107   rubio          negro  moreno / marron claro      suave  brillante
# 108   rubio          negro  moreno / marron claro  brillante      suave
# 109   rubio          negro  moreno / marron claro  brillante      suave
# 110   rubio          negro  moreno / marron claro  brillante  brillante
# 111   rubio          negro  moreno / marron claro  brillante  brillante
# 112   rubio  marron oscuro              melocoton      suave      suave
# 113   rubio  marron oscuro              melocoton      suave      suave
# 114   rubio  marron oscuro              melocoton      suave  brillante
# 115   rubio  marron oscuro              melocoton      suave  brillante
# 116   rubio  marron oscuro              melocoton  brillante      suave
# 117   rubio  marron oscuro              melocoton  brillante      suave
# 118   rubio  marron oscuro              melocoton  brillante  brillante
# 119   rubio  marron oscuro              melocoton  brillante  brillante
# 120   rubio  marron oscuro        blanco / palido      suave      suave
# 121   rubio  marron oscuro        blanco / palido      suave      suave
# 122   rubio  marron oscuro        blanco / palido      suave  brillante
# 123   rubio  marron oscuro        blanco / palido      suave  brillante
# 124   rubio  marron oscuro        blanco / palido  brillante      suave
# 125   rubio  marron oscuro        blanco / palido  brillante      suave
# 126   rubio  marron oscuro        blanco / palido  brillante  brillante
# 127   rubio  marron oscuro        blanco / palido  brillante  brillante
# 128   rubio  marron oscuro                 rosada      suave      suave
# 129   rubio  marron oscuro                 rosada      suave      suave
# 130   rubio  marron oscuro                 rosada      suave  brillante
# 131   rubio  marron oscuro                 rosada      suave  brillante
# 132   rubio  marron oscuro                 rosada  brillante      suave
# 133   rubio  marron oscuro                 rosada  brillante      suave
# 134   rubio  marron oscuro                 rosada  brillante  brillante
# 135   rubio  marron oscuro                 rosada  brillante  brillante
# 136   rubio  marron oscuro                  negro      suave      suave
# 137   rubio  marron oscuro                  negro      suave      suave
# 138   rubio  marron oscuro                  negro      suave  brillante
# 139   rubio  marron oscuro                  negro      suave  brillante
# 140   rubio  marron oscuro                  negro  brillante      suave
# 141   rubio  marron oscuro                  negro  brillante      suave
# 142   rubio  marron oscuro                  negro  brillante  brillante
# 143   rubio  marron oscuro                  negro  brillante  brillante
# 144   rubio  marron oscuro            amarillento      suave      suave
# 145   rubio  marron oscuro            amarillento      suave      suave
# 146   rubio  marron oscuro            amarillento      suave  brillante
# 147   rubio  marron oscuro            amarillento      suave  brillante
# 148   rubio  marron oscuro            amarillento  brillante      suave
# 149   rubio  marron oscuro            amarillento  brillante      suave
# 150   rubio  marron oscuro            amarillento  brillante  brillante
# 151   rubio  marron oscuro            amarillento  brillante  brillante
# 152   rubio  marron oscuro  moreno claro / dorado      suave      suave
# 153   rubio  marron oscuro  moreno claro / dorado      suave      suave
# 154   rubio  marron oscuro  moreno claro / dorado      suave  brillante
# 155   rubio  marron oscuro  moreno claro / dorado      suave  brillante
# 156   rubio  marron oscuro  moreno claro / dorado  brillante      suave
# 157   rubio  marron oscuro  moreno claro / dorado  brillante      suave
# 158   rubio  marron oscuro  moreno claro / dorado  brillante  brillante
# 159   rubio  marron oscuro  moreno claro / dorado  brillante  brillante
# 160   rubio  marron oscuro  moreno / marron claro      suave      suave
# 161   rubio  marron oscuro  moreno / marron claro      suave      suave
# 162   rubio  marron oscuro  moreno / marron claro      suave  brillante
# 163   rubio  marron oscuro  moreno / marron claro      suave  brillante
# 164   rubio  marron oscuro  moreno / marron claro  brillante      suave
# 165   rubio  marron oscuro  moreno / marron claro  brillante      suave
# 166   rubio  marron oscuro  moreno / marron claro  brillante  brillante
# 167   rubio  marron oscuro  moreno / marron claro  brillante  brillante
# 168   rubio           azul              melocoton      suave      suave
# 169   rubio           azul              melocoton      suave      suave
# 170   rubio           azul              melocoton      suave  brillante
# 171   rubio           azul              melocoton      suave  brillante
# 172   rubio           azul              melocoton  brillante      suave
# 173   rubio           azul              melocoton  brillante      suave
# 174   rubio           azul              melocoton  brillante  brillante
# 175   rubio           azul              melocoton  brillante  brillante
# 176   rubio           azul        blanco / palido      suave      suave
# 177   rubio           azul        blanco / palido      suave      suave
# 178   rubio           azul        blanco / palido      suave  brillante
# 179   rubio           azul        blanco / palido      suave  brillante
# 180   rubio           azul        blanco / palido  brillante      suave
# 181   rubio           azul        blanco / palido  brillante      suave
# 182   rubio           azul        blanco / palido  brillante  brillante
# 183   rubio           azul        blanco / palido  brillante  brillante
# 184   rubio           azul                 rosada      suave      suave
# 185   rubio           azul                 rosada      suave      suave
# 186   rubio           azul                 rosada      suave  brillante
# 187   rubio           azul                 rosada      suave  brillante
# 188   rubio           azul                 rosada  brillante      suave
# 189   rubio           azul                 rosada  brillante      suave
# 190   rubio           azul                 rosada  brillante  brillante
# 191   rubio           azul                 rosada  brillante  brillante
# 192   rubio           azul                  negro      suave      suave
# 193   rubio           azul                  negro      suave      suave
# 194   rubio           azul                  negro      suave  brillante
# 195   rubio           azul                  negro      suave  brillante
# 196   rubio           azul                  negro  brillante      suave
# 197   rubio           azul                  negro  brillante      suave
# 198   rubio           azul                  negro  brillante  brillante
# 199   rubio           azul                  negro  brillante  brillante
#
#     CROMA_PIEL TEMP_OJOS TEMP_PIEL TEMP_CAB VALOR_CAB VALOR_OJOS VALOR_PIEL  \
# ID
# 0        suave      frio      frio   calido     claro      claro      claro
# 1    brillante      frio      frio   calido     claro      claro      claro
# 2        suave      frio      frio   calido     claro      claro      claro
# 3    brillante      frio      frio   calido     claro      claro      claro
# 4        suave      frio      frio   calido     claro      claro      claro
# 5    brillante      frio      frio   calido     claro      claro      claro
# 6        suave      frio      frio   calido     claro      claro      claro
# 7    brillante      frio      frio   calido     claro      claro      claro
# 8        suave      frio      frio   calido     claro      claro      claro
# 9    brillante      frio      frio   calido     claro      claro      claro
# 10       suave      frio      frio   calido     claro      claro      claro
# 11   brillante      frio      frio   calido     claro      claro      claro
# 12       suave      frio      frio   calido     claro      claro      claro
# 13   brillante      frio      frio   calido     claro      claro      claro
# 14       suave      frio      frio   calido     claro      claro      claro
# 15   brillante      frio      frio   calido     claro      claro      claro
# 16       suave      frio      frio   calido     claro      claro      claro
# 17   brillante      frio      frio   calido     claro      claro      claro
# 18       suave      frio      frio   calido     claro      claro      claro
# 19   brillante      frio      frio   calido     claro      claro      claro
# 20       suave      frio      frio   calido     claro      claro      claro
# 21   brillante      frio      frio   calido     claro      claro      claro
# 22       suave      frio      frio   calido     claro      claro      claro
# 23   brillante      frio      frio   calido     claro      claro      claro
# 24       suave      frio    calido   calido     claro      claro     oscuro
# 25   brillante      frio    calido   calido     claro      claro     oscuro
# 26       suave      frio    calido   calido     claro      claro     oscuro
# 27   brillante      frio    calido   calido     claro      claro     oscuro
# 28       suave      frio    calido   calido     claro      claro     oscuro
# 29   brillante      frio    calido   calido     claro      claro     oscuro
# 30       suave      frio    calido   calido     claro      claro     oscuro
# 31   brillante      frio    calido   calido     claro      claro     oscuro
# 32       suave      frio    calido   calido     claro      claro      claro
# 33   brillante      frio    calido   calido     claro      claro      claro
# 34       suave      frio    calido   calido     claro      claro      claro
# 35   brillante      frio    calido   calido     claro      claro      claro
# 36       suave      frio    calido   calido     claro      claro      claro
# 37   brillante      frio    calido   calido     claro      claro      claro
# 38       suave      frio    calido   calido     claro      claro      claro
# 39   brillante      frio    calido   calido     claro      claro      claro
# 40       suave      frio    calido   calido     claro      claro     oscuro
# 41   brillante      frio    calido   calido     claro      claro     oscuro
# 42       suave      frio    calido   calido     claro      claro     oscuro
# 43   brillante      frio    calido   calido     claro      claro     oscuro
# 44       suave      frio    calido   calido     claro      claro     oscuro
# 45   brillante      frio    calido   calido     claro      claro     oscuro
# 46       suave      frio    calido   calido     claro      claro     oscuro
# 47   brillante      frio    calido   calido     claro      claro     oscuro
# 48       suave      frio      frio   calido     claro      claro     oscuro
# 49   brillante      frio      frio   calido     claro      claro     oscuro
# 50       suave      frio      frio   calido     claro      claro     oscuro
# 51   brillante      frio      frio   calido     claro      claro     oscuro
# 52       suave      frio      frio   calido     claro      claro     oscuro
# 53   brillante      frio      frio   calido     claro      claro     oscuro
# 54       suave      frio      frio   calido     claro      claro     oscuro
# 55   brillante      frio      frio   calido     claro      claro     oscuro
# 56       suave    calido      frio   calido     claro     oscuro      claro
# 57   brillante    calido      frio   calido     claro     oscuro      claro
# 58       suave    calido      frio   calido     claro     oscuro      claro
# 59   brillante    calido      frio   calido     claro     oscuro      claro
# 60       suave    calido      frio   calido     claro     oscuro      claro
# 61   brillante    calido      frio   calido     claro     oscuro      claro
# 62       suave    calido      frio   calido     claro     oscuro      claro
# 63   brillante    calido      frio   calido     claro     oscuro      claro
# 64       suave    calido      frio   calido     claro     oscuro      claro
# 65   brillante    calido      frio   calido     claro     oscuro      claro
# 66       suave    calido      frio   calido     claro     oscuro      claro
# 67   brillante    calido      frio   calido     claro     oscuro      claro
# 68       suave    calido      frio   calido     claro     oscuro      claro
# 69   brillante    calido      frio   calido     claro     oscuro      claro
# 70       suave    calido      frio   calido     claro     oscuro      claro
# 71   brillante    calido      frio   calido     claro     oscuro      claro
# 72       suave    calido      frio   calido     claro     oscuro      claro
# 73   brillante    calido      frio   calido     claro     oscuro      claro
# 74       suave    calido      frio   calido     claro     oscuro      claro
# 75   brillante    calido      frio   calido     claro     oscuro      claro
# 76       suave    calido      frio   calido     claro     oscuro      claro
# 77   brillante    calido      frio   calido     claro     oscuro      claro
# 78       suave    calido      frio   calido     claro     oscuro      claro
# 79   brillante    calido      frio   calido     claro     oscuro      claro
# 80       suave    calido    calido   calido     claro     oscuro     oscuro
# 81   brillante    calido    calido   calido     claro     oscuro     oscuro
# 82       suave    calido    calido   calido     claro     oscuro     oscuro
# 83   brillante    calido    calido   calido     claro     oscuro     oscuro
# 84       suave    calido    calido   calido     claro     oscuro     oscuro
# 85   brillante    calido    calido   calido     claro     oscuro     oscuro
# 86       suave    calido    calido   calido     claro     oscuro     oscuro
# 87   brillante    calido    calido   calido     claro     oscuro     oscuro
# 88       suave    calido    calido   calido     claro     oscuro      claro
# 89   brillante    calido    calido   calido     claro     oscuro      claro
# 90       suave    calido    calido   calido     claro     oscuro      claro
# 91   brillante    calido    calido   calido     claro     oscuro      claro
# 92       suave    calido    calido   calido     claro     oscuro      claro
# 93   brillante    calido    calido   calido     claro     oscuro      claro
# 94       suave    calido    calido   calido     claro     oscuro      claro
# 95   brillante    calido    calido   calido     claro     oscuro      claro
# 96       suave    calido    calido   calido     claro     oscuro     oscuro
# 97   brillante    calido    calido   calido     claro     oscuro     oscuro
# 98       suave    calido    calido   calido     claro     oscuro     oscuro
# 99   brillante    calido    calido   calido     claro     oscuro     oscuro
# 100      suave    calido    calido   calido     claro     oscuro     oscuro
# 101  brillante    calido    calido   calido     claro     oscuro     oscuro
# 102      suave    calido    calido   calido     claro     oscuro     oscuro
# 103  brillante    calido    calido   calido     claro     oscuro     oscuro
# 104      suave    calido      frio   calido     claro     oscuro     oscuro
# 105  brillante    calido      frio   calido     claro     oscuro     oscuro
# 106      suave    calido      frio   calido     claro     oscuro     oscuro
# 107  brillante    calido      frio   calido     claro     oscuro     oscuro
# 108      suave    calido      frio   calido     claro     oscuro     oscuro
# 109  brillante    calido      frio   calido     claro     oscuro     oscuro
# 110      suave    calido      frio   calido     claro     oscuro     oscuro
# 111  brillante    calido      frio   calido     claro     oscuro     oscuro
# 112      suave      frio      frio   calido     claro     oscuro      claro
# 113  brillante      frio      frio   calido     claro     oscuro      claro
# 114      suave      frio      frio   calido     claro     oscuro      claro
# 115  brillante      frio      frio   calido     claro     oscuro      claro
# 116      suave      frio      frio   calido     claro     oscuro      claro
# 117  brillante      frio      frio   calido     claro     oscuro      claro
# 118      suave      frio      frio   calido     claro     oscuro      claro
# 119  brillante      frio      frio   calido     claro     oscuro      claro
# 120      suave      frio      frio   calido     claro     oscuro      claro
# 121  brillante      frio      frio   calido     claro     oscuro      claro
# 122      suave      frio      frio   calido     claro     oscuro      claro
# 123  brillante      frio      frio   calido     claro     oscuro      claro
# 124      suave      frio      frio   calido     claro     oscuro      claro
# 125  brillante      frio      frio   calido     claro     oscuro      claro
# 126      suave      frio      frio   calido     claro     oscuro      claro
# 127  brillante      frio      frio   calido     claro     oscuro      claro
# 128      suave      frio      frio   calido     claro     oscuro      claro
# 129  brillante      frio      frio   calido     claro     oscuro      claro
# 130      suave      frio      frio   calido     claro     oscuro      claro
# 131  brillante      frio      frio   calido     claro     oscuro      claro
# 132      suave      frio      frio   calido     claro     oscuro      claro
# 133  brillante      frio      frio   calido     claro     oscuro      claro
# 134      suave      frio      frio   calido     claro     oscuro      claro
# 135  brillante      frio      frio   calido     claro     oscuro      claro
# 136      suave      frio    calido   calido     claro     oscuro     oscuro
# 137  brillante      frio    calido   calido     claro     oscuro     oscuro
# 138      suave      frio    calido   calido     claro     oscuro     oscuro
# 139  brillante      frio    calido   calido     claro     oscuro     oscuro
# 140      suave      frio    calido   calido     claro     oscuro     oscuro
# 141  brillante      frio    calido   calido     claro     oscuro     oscuro
# 142      suave      frio    calido   calido     claro     oscuro     oscuro
# 143  brillante      frio    calido   calido     claro     oscuro     oscuro
# 144      suave      frio    calido   calido     claro     oscuro      claro
# 145  brillante      frio    calido   calido     claro     oscuro      claro
# 146      suave      frio    calido   calido     claro     oscuro      claro
# 147  brillante      frio    calido   calido     claro     oscuro      claro
# 148      suave      frio    calido   calido     claro     oscuro      claro
# 149  brillante      frio    calido   calido     claro     oscuro      claro
# 150      suave      frio    calido   calido     claro     oscuro      claro
# 151  brillante      frio    calido   calido     claro     oscuro      claro
# 152      suave      frio    calido   calido     claro     oscuro     oscuro
# 153  brillante      frio    calido   calido     claro     oscuro     oscuro
# 154      suave      frio    calido   calido     claro     oscuro     oscuro
# 155  brillante      frio    calido   calido     claro     oscuro     oscuro
# 156      suave      frio    calido   calido     claro     oscuro     oscuro
# 157  brillante      frio    calido   calido     claro     oscuro     oscuro
# 158      suave      frio    calido   calido     claro     oscuro     oscuro
# 159  brillante      frio    calido   calido     claro     oscuro     oscuro
# 160      suave      frio      frio   calido     claro     oscuro     oscuro
# 161  brillante      frio      frio   calido     claro     oscuro     oscuro
# 162      suave      frio      frio   calido     claro     oscuro     oscuro
# 163  brillante      frio      frio   calido     claro     oscuro     oscuro
# 164      suave      frio      frio   calido     claro     oscuro     oscuro
# 165  brillante      frio      frio   calido     claro     oscuro     oscuro
# 166      suave      frio      frio   calido     claro     oscuro     oscuro
# 167  brillante      frio      frio   calido     claro     oscuro     oscuro
# 168      suave      frio      frio   calido     claro      claro      claro
# 169  brillante      frio      frio   calido     claro      claro      claro
# 170      suave      frio      frio   calido     claro      claro      claro
# 171  brillante      frio      frio   calido     claro      claro      claro
# 172      suave      frio      frio   calido     claro      claro      claro
# 173  brillante      frio      frio   calido     claro      claro      claro
# 174      suave      frio      frio   calido     claro      claro      claro
# 175  brillante      frio      frio   calido     claro      claro      claro
# 176      suave      frio      frio   calido     claro      claro      claro
# 177  brillante      frio      frio   calido     claro      claro      claro
# 178      suave      frio      frio   calido     claro      claro      claro
# 179  brillante      frio      frio   calido     claro      claro      claro
# 180      suave      frio      frio   calido     claro      claro      claro
# 181  brillante      frio      frio   calido     claro      claro      claro
# 182      suave      frio      frio   calido     claro      claro      claro
# 183  brillante      frio      frio   calido     claro      claro      claro
# 184      suave      frio      frio   calido     claro      claro      claro
# 185  brillante      frio      frio   calido     claro      claro      claro
# 186      suave      frio      frio   calido     claro      claro      claro
# 187  brillante      frio      frio   calido     claro      claro      claro
# 188      suave      frio      frio   calido     claro      claro      claro
# 189  brillante      frio      frio   calido     claro      claro      claro
# 190      suave      frio      frio   calido     claro      claro      claro
# 191  brillante      frio      frio   calido     claro      claro      claro
# 192      suave      frio    calido   calido     claro      claro     oscuro
# 193  brillante      frio    calido   calido     claro      claro     oscuro
# 194      suave      frio    calido   calido     claro      claro     oscuro
# 195  brillante      frio    calido   calido     claro      claro     oscuro
# 196      suave      frio    calido   calido     claro      claro     oscuro
# 197  brillante      frio    calido   calido     claro      claro     oscuro
# 198      suave      frio    calido   calido     claro      claro     oscuro
# 199  brillante      frio    calido   calido     claro      claro     oscuro
#
#     TEMP_TOTAL VALOR_TOTAL CROMA_TOTAL    PALETAS
# ID
# 0         frio       claro       suave      OTOÑO
# 1         frio       claro       suave      OTOÑO
# 2         frio       claro       suave      OTOÑO
# 3         frio       claro   brillante      OTOÑO
# 4         frio       claro       suave      OTOÑO
# 5         frio       claro   brillante      OTOÑO
# 6         frio       claro   brillante      OTOÑO
# 7         frio       claro   brillante      OTOÑO
# 8         frio       claro       suave      OTOÑO
# 9         frio       claro       suave      OTOÑO
# 10        frio       claro       suave      OTOÑO
# 11        frio       claro   brillante      OTOÑO
# 12        frio       claro       suave      OTOÑO
# 13        frio       claro   brillante      OTOÑO
# 14        frio       claro   brillante      OTOÑO
# 15        frio       claro   brillante      OTOÑO
# 16        frio       claro       suave      OTOÑO
# 17        frio       claro       suave      OTOÑO
# 18        frio       claro       suave      OTOÑO
# 19        frio       claro   brillante      OTOÑO
# 20        frio       claro       suave      OTOÑO
# 21        frio       claro   brillante      OTOÑO
# 22        frio       claro   brillante      OTOÑO
# 23        frio       claro   brillante      OTOÑO
# 24      calido       claro       suave  PRIMAVERA
# 25      calido       claro       suave  PRIMAVERA
# 26      calido       claro       suave  PRIMAVERA
# 27      calido       claro   brillante  PRIMAVERA
# 28      calido       claro       suave  PRIMAVERA
# 29      calido       claro   brillante  PRIMAVERA
# 30      calido       claro   brillante  PRIMAVERA
# 31      calido       claro   brillante  PRIMAVERA
# 32      calido       claro       suave  PRIMAVERA
# 33      calido       claro       suave  PRIMAVERA
# 34      calido       claro       suave  PRIMAVERA
# 35      calido       claro   brillante  PRIMAVERA
# 36      calido       claro       suave  PRIMAVERA
# 37      calido       claro   brillante  PRIMAVERA
# 38      calido       claro   brillante  PRIMAVERA
# 39      calido       claro   brillante  PRIMAVERA
# 40      calido       claro       suave  PRIMAVERA
# 41      calido       claro       suave  PRIMAVERA
# 42      calido       claro       suave  PRIMAVERA
# 43      calido       claro   brillante  PRIMAVERA
# 44      calido       claro       suave  PRIMAVERA
# 45      calido       claro   brillante  PRIMAVERA
# 46      calido       claro   brillante  PRIMAVERA
# 47      calido       claro   brillante  PRIMAVERA
# 48        frio       claro       suave      OTOÑO
# 49        frio       claro       suave      OTOÑO
# 50        frio       claro       suave      OTOÑO
# 51        frio       claro   brillante      OTOÑO
# 52        frio       claro       suave      OTOÑO
# 53        frio       claro   brillante      OTOÑO
# 54        frio       claro   brillante      OTOÑO
# 55        frio       claro   brillante      OTOÑO
# 56      calido       claro       suave  PRIMAVERA
# 57      calido       claro       suave  PRIMAVERA
# 58      calido       claro       suave  PRIMAVERA
# 59      calido       claro   brillante  PRIMAVERA
# 60      calido       claro       suave  PRIMAVERA
# 61      calido       claro   brillante  PRIMAVERA
# 62      calido       claro   brillante  PRIMAVERA
# 63      calido       claro   brillante  PRIMAVERA
# 64      calido       claro       suave  PRIMAVERA
# 65      calido       claro       suave  PRIMAVERA
# 66      calido       claro       suave  PRIMAVERA
# 67      calido       claro   brillante  PRIMAVERA
# 68      calido       claro       suave  PRIMAVERA
# 69      calido       claro   brillante  PRIMAVERA
# 70      calido       claro   brillante  PRIMAVERA
# 71      calido       claro   brillante  PRIMAVERA
# 72      calido       claro       suave  PRIMAVERA
# 73      calido       claro       suave  PRIMAVERA
# 74      calido       claro       suave  PRIMAVERA
# 75      calido       claro   brillante  PRIMAVERA
# 76      calido       claro       suave  PRIMAVERA
# 77      calido       claro   brillante  PRIMAVERA
# 78      calido       claro   brillante  PRIMAVERA
# 79      calido       claro   brillante  PRIMAVERA
# 80      calido      oscuro       suave     VERANO
# 81      calido      oscuro       suave     VERANO
# 82      calido      oscuro       suave     VERANO
# 83      calido      oscuro   brillante  PRIMAVERA
# 84      calido      oscuro       suave     VERANO
# 85      calido      oscuro   brillante  PRIMAVERA
# 86      calido      oscuro   brillante  PRIMAVERA
# 87      calido      oscuro   brillante  PRIMAVERA
# 88      calido       claro       suave  PRIMAVERA
# 89      calido       claro       suave  PRIMAVERA
# 90      calido       claro       suave  PRIMAVERA
# 91      calido       claro   brillante  PRIMAVERA
# 92      calido       claro       suave  PRIMAVERA
# 93      calido       claro   brillante  PRIMAVERA
# 94      calido       claro   brillante  PRIMAVERA
# 95      calido       claro   brillante  PRIMAVERA
# 96      calido      oscuro       suave     VERANO
# 97      calido      oscuro       suave     VERANO
# 98      calido      oscuro       suave     VERANO
# 99      calido      oscuro   brillante  PRIMAVERA
# 100     calido      oscuro       suave     VERANO
# 101     calido      oscuro   brillante  PRIMAVERA
# 102     calido      oscuro   brillante  PRIMAVERA
# 103     calido      oscuro   brillante  PRIMAVERA
# 104     calido      oscuro       suave     VERANO
# 105     calido      oscuro       suave     VERANO
# 106     calido      oscuro       suave     VERANO
# 107     calido      oscuro   brillante  PRIMAVERA
# 108     calido      oscuro       suave     VERANO
# 109     calido      oscuro   brillante  PRIMAVERA
# 110     calido      oscuro   brillante  PRIMAVERA
# 111     calido      oscuro   brillante  PRIMAVERA
# 112       frio       claro       suave      OTOÑO
# 113       frio       claro       suave      OTOÑO
# 114       frio       claro       suave      OTOÑO
# 115       frio       claro   brillante      OTOÑO
# 116       frio       claro       suave      OTOÑO
# 117       frio       claro   brillante      OTOÑO
# 118       frio       claro   brillante      OTOÑO
# 119       frio       claro   brillante      OTOÑO
# 120       frio       claro       suave      OTOÑO
# 121       frio       claro       suave      OTOÑO
# 122       frio       claro       suave      OTOÑO
# 123       frio       claro   brillante      OTOÑO
# 124       frio       claro       suave      OTOÑO
# 125       frio       claro   brillante      OTOÑO
# 126       frio       claro   brillante      OTOÑO
# 127       frio       claro   brillante      OTOÑO
# 128       frio       claro       suave      OTOÑO
# 129       frio       claro       suave      OTOÑO
# 130       frio       claro       suave      OTOÑO
# 131       frio       claro   brillante      OTOÑO
# 132       frio       claro       suave      OTOÑO
# 133       frio       claro   brillante      OTOÑO
# 134       frio       claro   brillante      OTOÑO
# 135       frio       claro   brillante      OTOÑO
# 136     calido      oscuro       suave     VERANO
# 137     calido      oscuro       suave     VERANO
# 138     calido      oscuro       suave     VERANO
# 139     calido      oscuro   brillante  PRIMAVERA
# 140     calido      oscuro       suave     VERANO
# 141     calido      oscuro   brillante  PRIMAVERA
# 142     calido      oscuro   brillante  PRIMAVERA
# 143     calido      oscuro   brillante  PRIMAVERA
# 144     calido       claro       suave  PRIMAVERA
# 145     calido       claro       suave  PRIMAVERA
# 146     calido       claro       suave  PRIMAVERA
# 147     calido       claro   brillante  PRIMAVERA
# 148     calido       claro       suave  PRIMAVERA
# 149     calido       claro   brillante  PRIMAVERA
# 150     calido       claro   brillante  PRIMAVERA
# 151     calido       claro   brillante  PRIMAVERA
# 152     calido      oscuro       suave     VERANO
# 153     calido      oscuro       suave     VERANO
# 154     calido      oscuro       suave     VERANO
# 155     calido      oscuro   brillante  PRIMAVERA
# 156     calido      oscuro       suave     VERANO
# 157     calido      oscuro   brillante  PRIMAVERA
# 158     calido      oscuro   brillante  PRIMAVERA
# 159     calido      oscuro   brillante  PRIMAVERA
# 160       frio      oscuro       suave      OTOÑO
# 161       frio      oscuro       suave      OTOÑO
# 162       frio      oscuro       suave      OTOÑO
# 163       frio      oscuro   brillante   INVIERNO
# 164       frio      oscuro       suave      OTOÑO
# 165       frio      oscuro   brillante   INVIERNO
# 166       frio      oscuro   brillante   INVIERNO
# 167       frio      oscuro   brillante   INVIERNO
# 168       frio       claro       suave      OTOÑO
# 169       frio       claro       suave      OTOÑO
# 170       frio       claro       suave      OTOÑO
# 171       frio       claro   brillante      OTOÑO
# 172       frio       claro       suave      OTOÑO
# 173       frio       claro   brillante      OTOÑO
# 174       frio       claro   brillante      OTOÑO
# 175       frio       claro   brillante      OTOÑO
# 176       frio       claro       suave      OTOÑO
# 177       frio       claro       suave      OTOÑO
# 178       frio       claro       suave      OTOÑO
# 179       frio       claro   brillante      OTOÑO
# 180       frio       claro       suave      OTOÑO
# 181       frio       claro   brillante      OTOÑO
# 182       frio       claro   brillante      OTOÑO
# 183       frio       claro   brillante      OTOÑO
# 184       frio       claro       suave      OTOÑO
# 185       frio       claro       suave      OTOÑO
# 186       frio       claro       suave      OTOÑO
# 187       frio       claro   brillante      OTOÑO
# 188       frio       claro       suave      OTOÑO
# 189       frio       claro   brillante      OTOÑO
# 190       frio       claro   brillante      OTOÑO
# 191       frio       claro   brillante      OTOÑO
# 192     calido       claro       suave  PRIMAVERA
# 193     calido       claro       suave  PRIMAVERA
# 194     calido       claro       suave  PRIMAVERA
# 195     calido       claro   brillante  PRIMAVERA
# 196     calido       claro       suave  PRIMAVERA
# 197     calido       claro   brillante  PRIMAVERA
# 198     calido       claro   brillante  PRIMAVERA
# 199     calido       claro   brillante  PRIMAVERA
